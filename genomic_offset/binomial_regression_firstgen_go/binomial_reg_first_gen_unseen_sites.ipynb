# %%
import pandas as pd
import pickle

# %%
import statsmodels.api as sm
from statsmodels.formula.api import glm

# %%
from sklearn.preprocessing import StandardScaler

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
#finalgen_samples = pd.read_csv('../final_gen.csv')['sample_name']
first_gen = pd.read_csv('../key_files/generation_1_sample_names.txt',header=None)[0]
samples = first_gen.to_list()

#clim_sites_during_exp = pd.read_csv('/carnegie/nobackup/scratch/tbellagio/grene/data/bio')
clim_sites_during_exp = pd.read_csv('../key_files/bioclimvars_sites_era5_year_2018.csv')

sites_af = pd.Series(samples).str.split('_').str[0].astype(int)

sites_af.name = 'site'

# %%
unseen_sites = [7, 50, 56, 21, 41, 47]

# Convert the list to a Series and concatenate with the existing Series
new_series = pd.Series(unseen_sites, name='site')

# %%
sites_af = pd.concat([sites_af, new_series], ignore_index=True)

# %%
sites_af
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 327    50
# 328    56
# 329    21
# 330    41
# 331    47
# Name: site, Length: 332, dtype: int64

# %%
env = sites_af.reset_index().merge(clim_sites_during_exp).drop(['index'],axis=1)

# %%
#env = env.drop_duplicates()

# %%
env_variable = env['bio1']

# %%
# Standardize the environmental variable
scaler = StandardScaler()
env_variable_scaled = scaler.fit_transform(env_variable.values.reshape(-1, 1))

# %%
pd.DataFrame(env_variable_scaled).to_csv('env.csv',index=None)

# %%
env_site_scaled = pd.concat([env['site'],pd.Series(env_variable_scaled.flatten())],axis=1)

# %%
env_site_scaled.columns = ['site', 'env_scaled']

# %%
env_site_scaled
# Out:
#      site  env_scaled
# 0       1   -0.779581
# 1       1   -0.779581
# 2       1   -0.779581
# 3       1   -0.779581
# 4       1   -0.779581
# ..    ...         ...
# 327    50   -1.101596
# 328    56   -1.778135
# 329    21   -0.715968
# 330    41   -0.642677
# 331    47   -0.312674
#
# [332 rows x 2 columns]

# %%
env_site_scaled.to_csv('env_site_scaled.csv',index=None)

# %%
import os

# %%
files = os.listdir('../baypass_first_gen/individual_gfiles/')

# %%
partitions = [int(file.split('_')[1].replace('.txt', '')) for file in files if '.txt' in file]

# %%
partitions.sort()

# %%
partitions[-1]
# Out:
# 201

# %%
len(partitions)
# Out:
# 202

# %%
pwd -P
# Out:
# '/carnegie/nobackup/scratch/tbellagio/gea_grene-net/binomial_regression_firstgen_go'

# %%
import random
import subprocess

# %%
samples = pd.read_csv('../key_files/merged_sample_table.csv')

# %%
samples = samples[samples['generation'] ==1]

# %%
samples = samples['sample_name'].to_list()

# %%
import pickle

def create_fake_cv(samples, unseen_sites):
    """
    Creates a fake cross-validation file where all samples are used for training
    and a single fake sample name is used for each unseen site in the test set.

    Parameters:
    samples (list): Original list of cross-validation splits.
    unseen_sites (list): List of unseen site numbers.

    Returns:
    list: New list of cross-validation splits with fake samples for unseen sites.
    """
    # Flatten the original sample list to get all unique samples
    #all_samples = sorted(set([sample for split in samples for sample in split[0]]))
    
    # Create the new fake splits
    fake_splits = []
    for site in unseen_sites:
        train = samples  # Use all samples for training
        # Create one fake sample name for each unseen site
        test = [f"{site}_1_1"]
        # Append the new split as a tuple of (train, test)
        fake_splits.append((train, test))
    
    return fake_splits

# %%
# Unseen site numbers
unseen_sites = [7, 50, 56, 21, 41, 47]

# Create fake cross-validation splits
fake_cv_splits = create_fake_cv(samples, unseen_sites)

# Save the fake splits to a new pickle file
output_path = '../jacknife_first_gen/fake_splits_samples_for_unseen_sites.pkl'
with open(output_path, 'wb') as file:
    pickle.dump(fake_cv_splits, file)

print(f"Fake cross-validation splits saved to {output_path}")
# Out:
# Fake cross-validation splits saved to ../jacknife_first_gen/fake_splits_samples_for_unseen_sites.pkl

# %%
file_path = '../jacknife_first_gen/fake_splits_samples_for_unseen_sites.pkl'

# Open and load the .pkl file
with open(file_path, 'rb') as file:
    samples_fake = pickle.load(file)

# %%
len(samples_fake)
# Out:
# 6

# %%
len(samples_fake[0][0])
# Out:
# 326

# %%
samples_fake[0][1]
# Out:
# ['7_1_1']

# %%
samples_fake[1][1]
# Out:
# ['50_1_1']

# %%
# Loop through splits 0 to 31
for split in range(len(samples)):
    # Define the folder path
    folder_path = f'results_sites_unseen/split_{split}'
    # Create the directory (makedirs allows creating intermediate directories if they don't exist)
    os.makedirs(folder_path, exist_ok=True)

# %%
pwd
# Out:
# '/carnegie/nobackup/scratch/tbellagio/gea_grene-net/binomial_regression_firstgen_go'

# %%
len(samples_fake)
# Out:
# 6

# %%
for split in range(len(samples_fake)):
    print(split)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# create sbatch files to submit on cedar server
shfiles = []
for split in [6]: #range(len(samples_fake)):
    for partition in partitions:
        seed = random.randint(1,100000000)
        file = f'shfiles/partition_{partition}_{split}.sh'
        cmd = f'python run_partition_binomial_reg_first_gen_unseen_sites.py {partition} {split}'
        text = f'''#!/bin/bash
#SBATCH --job-name=run_partition_binomial_reg{partition}_{split}
#SBATCH --time=1:00:00  # Time limit set to 4 hours
#SBATCH --ntasks=1
#SBATCH --mem-per-cpu=30gb
#SBATCH --output=run_partition_binomial_reg_{partition}_{split}_%j.out
#SBATCH --mail-user=tbellagio@carnegiescience.edu
#SBATCH --mail-type=FAIL

module load python/3.11_conda
conda activate /home/tbellagio/miniforge3/envs/pipeline_snakemake
export LD_LIBRARY_PATH="/home/tbellagio/miniforge3/envs/run_baypass/lib:$LD_LIBRARY_PATH"
cd /carnegie/nobackup/scratch/tbellagio/gea_grene-net/binomial_regression_firstgen_go
{cmd}

'''
        with open(file, 'w') as o:
            o.write("%s" % text)
        shfiles.append(file)

# %%
subprocess.run(["sbatch", shfiles[0]], check=True)
# Out:
# Submitted batch job 64725
# CompletedProcess(args=['sbatch', 'shfiles/partition_0_0.sh'], returncode=0)

# %%
## now run the shfiles
for shfile in shfiles:
    # Submit each sbatch script to the SLURM scheduler
    subprocess.run(["sbatch", shfile], check=True)
# Out:
# Submitted batch job 64726
# Submitted batch job 64727
# Submitted batch job 64728
# Submitted batch job 64729
# Submitted batch job 64730
# Submitted batch job 64731
# Submitted batch job 64732
# Submitted batch job 64733
# Submitted batch job 64734
# Submitted batch job 64735
# Submitted batch job 64736
# Submitted batch job 64737
# Submitted batch job 64738
# Submitted batch job 64739
# Submitted batch job 64740
# Submitted batch job 64741
# Submitted batch job 64742
# Submitted batch job 64743
# Submitted batch job 64744
# Submitted batch job 64745
# Submitted batch job 64746
# Submitted batch job 64747
# Submitted batch job 64748
# Submitted batch job 64749
# Submitted batch job 64750
# Submitted batch job 64751
# Submitted batch job 64752
# Submitted batch job 64753
# Submitted batch job 64754
# Submitted batch job 64755
# Submitted batch job 64756
# Submitted batch job 64757
# Submitted batch job 64758
# Submitted batch job 64759
# Submitted batch job 64760
# Submitted batch job 64761
# Submitted batch job 64762
# Submitted batch job 64763
# Submitted batch job 64764
# Submitted batch job 64765
# Submitted batch job 64766
# Submitted batch job 64767
# Submitted batch job 64768
# Submitted batch job 64769
# Submitted batch job 64770
# Submitted batch job 64771
# Submitted batch job 64772
# Submitted batch job 64773
# Submitted batch job 64774
# Submitted batch job 64775
# Submitted batch job 64776
# Submitted batch job 64777
# Submitted batch job 64778
# Submitted batch job 64779
# Submitted batch job 64780
# Submitted batch job 64781
# Submitted batch job 64782
# Submitted batch job 64783
# Submitted batch job 64784
# Submitted batch job 64785
# Submitted batch job 64786
# Submitted batch job 64787
# Submitted batch job 64788
# Submitted batch job 64789
# Submitted batch job 64790
# Submitted batch job 64791
# Submitted batch job 64792
# Submitted batch job 64793
# Submitted batch job 64794
# Submitted batch job 64795
# Submitted batch job 64796
# Submitted batch job 64797
# Submitted batch job 64798
# Submitted batch job 64799
# Submitted batch job 64800
# Submitted batch job 64801
# Submitted batch job 64802
# Submitted batch job 64803
# Submitted batch job 64804
# Submitted batch job 64805
# Submitted batch job 64806
# Submitted batch job 64807
# Submitted batch job 64808
# Submitted batch job 64809
# Submitted batch job 64810
# Submitted batch job 64811
# Submitted batch job 64812
# Submitted batch job 64813
# Submitted batch job 64814
# Submitted batch job 64815
# Submitted batch job 64816
# Submitted batch job 64817
# Submitted batch job 64818
# Submitted batch job 64819
# Submitted batch job 64820
# Submitted batch job 64821
# Submitted batch job 64822
# Submitted batch job 64823
# Submitted batch job 64824
# Submitted batch job 64825
# Submitted batch job 64826
# Submitted batch job 64827
# Submitted batch job 64828
# Submitted batch job 64829
# Submitted batch job 64830
# Submitted batch job 64831
# Submitted batch job 64832
# Submitted batch job 64833
# Submitted batch job 64834
# Submitted batch job 64835
# Submitted batch job 64836
# Submitted batch job 64837
# Submitted batch job 64838
# Submitted batch job 64839
# Submitted batch job 64840
# Submitted batch job 64841
# Submitted batch job 64842
# Submitted batch job 64843
# Submitted batch job 64844
# Submitted batch job 64845
# Submitted batch job 64846
# Submitted batch job 64847
# Submitted batch job 64848
# Submitted batch job 64849
# Submitted batch job 64850
# Submitted batch job 64851
# Submitted batch job 64852
# Submitted batch job 64853
# Submitted batch job 64854
# Submitted batch job 64855
# Submitted batch job 64856
# Submitted batch job 64857
# Submitted batch job 64858
# Submitted batch job 64859
# Submitted batch job 64860
# Submitted batch job 64861
# Submitted batch job 64862
# Submitted batch job 64863
# Submitted batch job 64864
# Submitted batch job 64865
# Submitted batch job 64866
# Submitted batch job 64867
# Submitted batch job 64868
# Submitted batch job 64869
# Submitted batch job 64870
# Submitted batch job 64871
# Submitted batch job 64872
# Submitted batch job 64873
# Submitted batch job 64874
# Submitted batch job 64875
# Submitted batch job 64876
# Submitted batch job 64877
# Submitted batch job 64878
# Submitted batch job 64879
# Submitted batch job 64880
# Submitted batch job 64881
# Submitted batch job 64882
# Submitted batch job 64883
# Submitted batch job 64884
# Submitted batch job 64885
# Submitted batch job 64886
# Submitted batch job 64887
# Submitted batch job 64888
# Submitted batch job 64889
# Submitted batch job 64890
# Submitted batch job 64891
# Submitted batch job 64892
# Submitted batch job 64893
# Submitted batch job 64894
# Submitted batch job 64895
# Submitted batch job 64896
# Submitted batch job 64897
# Submitted batch job 64898
# Submitted batch job 64899
# Submitted batch job 64900
# Submitted batch job 64901
# Submitted batch job 64902
# Submitted batch job 64903
# Submitted batch job 64904
# Submitted batch job 64905
# Submitted batch job 64906
# Submitted batch job 64907
# Submitted batch job 64908
# Submitted batch job 64909
# Submitted batch job 64910
# Submitted batch job 64911
# Submitted batch job 64912
# Submitted batch job 64913
# Submitted batch job 64914
# Submitted batch job 64915
# Submitted batch job 64916
# Submitted batch job 64917
# Submitted batch job 64918
# Submitted batch job 64919
# Submitted batch job 64920
# Submitted batch job 64921
# Submitted batch job 64922
# Submitted batch job 64923
# Submitted batch job 64924
# Submitted batch job 64925
# Submitted batch job 64926
# Submitted batch job 64927
# Submitted batch job 64928
# Submitted batch job 64929
# Submitted batch job 64930
# Submitted batch job 64931
# Submitted batch job 64932
# Submitted batch job 64933
# Submitted batch job 64934
# Submitted batch job 64935
# Submitted batch job 64936
# Submitted batch job 64937
# Submitted batch job 64938
# Submitted batch job 64939
# Submitted batch job 64940
# Submitted batch job 64941
# Submitted batch job 64942
# Submitted batch job 64943
# Submitted batch job 64944
# Submitted batch job 64945
# Submitted batch job 64946
# Submitted batch job 64947
# Submitted batch job 64948
# Submitted batch job 64949
# Submitted batch job 64950
# Submitted batch job 64951
# Submitted batch job 64952
# Submitted batch job 64953
# Submitted batch job 64954
# Submitted batch job 64955
# Submitted batch job 64956
# Submitted batch job 64957
# Submitted batch job 64958
# Submitted batch job 64959
# Submitted batch job 64960
# Submitted batch job 64961
# Submitted batch job 64962
# Submitted batch job 64963
# Submitted batch job 64964
# Submitted batch job 64965
# Submitted batch job 64966
# Submitted batch job 64967
# Submitted batch job 64968
# Submitted batch job 64969
# Submitted batch job 64970
# Submitted batch job 64971
# Submitted batch job 64972
# Submitted batch job 64973
# Submitted batch job 64974
# Submitted batch job 64975
# Submitted batch job 64976
# Submitted batch job 64977
# Submitted batch job 64978
# Submitted batch job 64979
# Submitted batch job 64980
# Submitted batch job 64981
# Submitted batch job 64982
# Submitted batch job 64983
# Submitted batch job 64984
# Submitted batch job 64985
# Submitted batch job 64986
# Submitted batch job 64987
# Submitted batch job 64988
# Submitted batch job 64989
# Submitted batch job 64990
# Submitted batch job 64991
# Submitted batch job 64992
# Submitted batch job 64993
# Submitted batch job 64994
# Submitted batch job 64995
# Submitted batch job 64996
# Submitted batch job 64997
# Submitted batch job 64998
# Submitted batch job 64999
# Submitted batch job 65000
# Submitted batch job 65001
# Submitted batch job 65002
# Submitted batch job 65003
# Submitted batch job 65004
# Submitted batch job 65005
# Submitted batch job 65006
# Submitted batch job 65007
# Submitted batch job 65008
# Submitted batch job 65009
# Submitted batch job 65010
# Submitted batch job 65011
# Submitted batch job 65012
# Submitted batch job 65013
# Submitted batch job 65014
# Submitted batch job 65015
# Submitted batch job 65016
# Submitted batch job 65017
# Submitted batch job 65018
# Submitted batch job 65019
# Submitted batch job 65020
# Submitted batch job 65021
# Submitted batch job 65022
# Submitted batch job 65023
# Submitted batch job 65024
# Submitted batch job 65025
# Submitted batch job 65026
# Submitted batch job 65027
# Submitted batch job 65028
# Submitted batch job 65029
# Submitted batch job 65030
# Submitted batch job 65031
# Submitted batch job 65032
# Submitted batch job 65033
# Submitted batch job 65034
# Submitted batch job 65035
# Submitted batch job 65036
# Submitted batch job 65037
# Submitted batch job 65038
# Submitted batch job 65039
# Submitted batch job 65040
# Submitted batch job 65041
# Submitted batch job 65042
# Submitted batch job 65043
# Submitted batch job 65044
# Submitted batch job 65045
# Submitted batch job 65046
# Submitted batch job 65047
# Submitted batch job 65048
# Submitted batch job 65049
# Submitted batch job 65050
# Submitted batch job 65051
# Submitted batch job 65052
# Submitted batch job 65053
# Submitted batch job 65054
# Submitted batch job 65055
# Submitted batch job 65056
# Submitted batch job 65057
# Submitted batch job 65058
# Submitted batch job 65059
# Submitted batch job 65060
# Submitted batch job 65061
# Submitted batch job 65062
# Submitted batch job 65063
# Submitted batch job 65064
# Submitted batch job 65065
# Submitted batch job 65066
# Submitted batch job 65067
# Submitted batch job 65068
# Submitted batch job 65069
# Submitted batch job 65070
# Submitted batch job 65071
# Submitted batch job 65072
# Submitted batch job 65073
# Submitted batch job 65074
# Submitted batch job 65075
# Submitted batch job 65076
# Submitted batch job 65077
# Submitted batch job 65078
# Submitted batch job 65079
# Submitted batch job 65080
# Submitted batch job 65081
# Submitted batch job 65082
# Submitted batch job 65083
# Submitted batch job 65084
# Submitted batch job 65085
# Submitted batch job 65086
# Submitted batch job 65087
# Submitted batch job 65088
# Submitted batch job 65089
# Submitted batch job 65090
# Submitted batch job 65091
# Submitted batch job 65092
# Submitted batch job 65093
# Submitted batch job 65094
# Submitted batch job 65095
# Submitted batch job 65096
# Submitted batch job 65097
# Submitted batch job 65098
# Submitted batch job 65099
# Submitted batch job 65100
# Submitted batch job 65101
# Submitted batch job 65102
# Submitted batch job 65103
# Submitted batch job 65104
# Submitted batch job 65105
# Submitted batch job 65106
# Submitted batch job 65107
# Submitted batch job 65108
# Submitted batch job 65109
# Submitted batch job 65110
# Submitted batch job 65111
# Submitted batch job 65112
# Submitted batch job 65113
# Submitted batch job 65114
# Submitted batch job 65115
# Submitted batch job 65116
# Submitted batch job 65117
# Submitted batch job 65118
# Submitted batch job 65119
# Submitted batch job 65120
# Submitted batch job 65121
# Submitted batch job 65122
# Submitted batch job 65123
# Submitted batch job 65124
# Submitted batch job 65125
# Submitted batch job 65126
# Submitted batch job 65127
# Submitted batch job 65128
# Submitted batch job 65129
# Submitted batch job 65130
# Submitted batch job 65131
# Submitted batch job 65132
# Submitted batch job 65133
# Submitted batch job 65134
# Submitted batch job 65135
# Submitted batch job 65136
# Submitted batch job 65137
# Submitted batch job 65138
# Submitted batch job 65139
# Submitted batch job 65140
# Submitted batch job 65141
# Submitted batch job 65142
# Submitted batch job 65143
# Submitted batch job 65144
# Submitted batch job 65145
# Submitted batch job 65146
# Submitted batch job 65147
# Submitted batch job 65148
# Submitted batch job 65149
# Submitted batch job 65150
# Submitted batch job 65151
# Submitted batch job 65152
# Submitted batch job 65153
# Submitted batch job 65154
# Submitted batch job 65155
# Submitted batch job 65156
# Submitted batch job 65157
# Submitted batch job 65158
# Submitted batch job 65159
# Submitted batch job 65160
# Submitted batch job 65161
# Submitted batch job 65162
# Submitted batch job 65163
# Submitted batch job 65164
# Submitted batch job 65165
# Submitted batch job 65166
# Submitted batch job 65167
# Submitted batch job 65168
# Submitted batch job 65169
# Submitted batch job 65170
# Submitted batch job 65171
# Submitted batch job 65172
# Submitted batch job 65173
# Submitted batch job 65174
# Submitted batch job 65175
# Submitted batch job 65176
# Submitted batch job 65177
# Submitted batch job 65178
# Submitted batch job 65179
# Submitted batch job 65180
# Submitted batch job 65181
# Submitted batch job 65182
# Submitted batch job 65183
# Submitted batch job 65184
# Submitted batch job 65185
# Submitted batch job 65186
# Submitted batch job 65187
# Submitted batch job 65188
# Submitted batch job 65189
# Submitted batch job 65190
# Submitted batch job 65191
# Submitted batch job 65192
# Submitted batch job 65193
# Submitted batch job 65194
# Submitted batch job 65195
# Submitted batch job 65196
# Submitted batch job 65197
# Submitted batch job 65198
# Submitted batch job 65199
# Submitted batch job 65200
# Submitted batch job 65201
# Submitted batch job 65202
# Submitted batch job 65203
# Submitted batch job 65204
# Submitted batch job 65205
# Submitted batch job 65206
# Submitted batch job 65207
# Submitted batch job 65208
# Submitted batch job 65209
# Submitted batch job 65210
# Submitted batch job 65211
# Submitted batch job 65212
# Submitted batch job 65213
# Submitted batch job 65214
# Submitted batch job 65215
# Submitted batch job 65216
# Submitted batch job 65217
# Submitted batch job 65218
# Submitted batch job 65219
# Submitted batch job 65220
# Submitted batch job 65221
# Submitted batch job 65222
# Submitted batch job 65223
# Submitted batch job 65224
# Submitted batch job 65225
# Submitted batch job 65226
# Submitted batch job 65227
# Submitted batch job 65228
# Submitted batch job 65229
# Submitted batch job 65230
# Submitted batch job 65231
# Submitted batch job 65232
# Submitted batch job 65233
# Submitted batch job 65234
# Submitted batch job 65235
# Submitted batch job 65236
# Submitted batch job 65237
# Submitted batch job 65238
# Submitted batch job 65239
# Submitted batch job 65240
# Submitted batch job 65241
# Submitted batch job 65242
# Submitted batch job 65243
# Submitted batch job 65244
# Submitted batch job 65245
# Submitted batch job 65246
# Submitted batch job 65247
# Submitted batch job 65248
# Submitted batch job 65249
# Submitted batch job 65250
# Submitted batch job 65251
# Submitted batch job 65252
# Submitted batch job 65253
# Submitted batch job 65254
# Submitted batch job 65255
# Submitted batch job 65256
# Submitted batch job 65257
# Submitted batch job 65258
# Submitted batch job 65259
# Submitted batch job 65260
# Submitted batch job 65261
# Submitted batch job 65262
# Submitted batch job 65263
# Submitted batch job 65264
# Submitted batch job 65265
# Submitted batch job 65266
# Submitted batch job 65267
# Submitted batch job 65268
# Submitted batch job 65269
# Submitted batch job 65270
# Submitted batch job 65271
# Submitted batch job 65272
# Submitted batch job 65273
# Submitted batch job 65274
# Submitted batch job 65275
# Submitted batch job 65276
# Submitted batch job 65277
# Submitted batch job 65278
# Submitted batch job 65279
# Submitted batch job 65280
# Submitted batch job 65281
# Submitted batch job 65282
# Submitted batch job 65283
# Submitted batch job 65284
# Submitted batch job 65285
# Submitted batch job 65286
# Submitted batch job 65287
# Submitted batch job 65288
# Submitted batch job 65289
# Submitted batch job 65290
# Submitted batch job 65291
# Submitted batch job 65292
# Submitted batch job 65293
# Submitted batch job 65294
# Submitted batch job 65295
# Submitted batch job 65296
# Submitted batch job 65297
# Submitted batch job 65298
# Submitted batch job 65299
# Submitted batch job 65300
# Submitted batch job 65301
# Submitted batch job 65302
# Submitted batch job 65303
# Submitted batch job 65304
# Submitted batch job 65305
# Submitted batch job 65306
# Submitted batch job 65307
# Submitted batch job 65308
# Submitted batch job 65309
# Submitted batch job 65310
# Submitted batch job 65311
# Submitted batch job 65312
# Submitted batch job 65313
# Submitted batch job 65314
# Submitted batch job 65315
# Submitted batch job 65316
# Submitted batch job 65317
# Submitted batch job 65318
# Submitted batch job 65319
# Submitted batch job 65320
# Submitted batch job 65321
# Submitted batch job 65322
# Submitted batch job 65323
# Submitted batch job 65324
# Submitted batch job 65325
# Submitted batch job 65326
# Submitted batch job 65327
# Submitted batch job 65328
# Submitted batch job 65329
# Submitted batch job 65330
# Submitted batch job 65331
# Submitted batch job 65332
# Submitted batch job 65333
# Submitted batch job 65334
# Submitted batch job 65335
# Submitted batch job 65336
# Submitted batch job 65337
# Submitted batch job 65338
# Submitted batch job 65339
# Submitted batch job 65340
# Submitted batch job 65341
# Submitted batch job 65342
# Submitted batch job 65343
# Submitted batch job 65344
# Submitted batch job 65345
# Submitted batch job 65346
# Submitted batch job 65347
# Submitted batch job 65348
# Submitted batch job 65349
# Submitted batch job 65350
# Submitted batch job 65351
# Submitted batch job 65352
# Submitted batch job 65353
# Submitted batch job 65354
# Submitted batch job 65355
# Submitted batch job 65356
# Submitted batch job 65357
# Submitted batch job 65358
# Submitted batch job 65359
# Submitted batch job 65360
# Submitted batch job 65361
# Submitted batch job 65362
# Submitted batch job 65363
# Submitted batch job 65364
# Submitted batch job 65365
# Submitted batch job 65366
# Submitted batch job 65367
# Submitted batch job 65368
# Submitted batch job 65369
# Submitted batch job 65370
# Submitted batch job 65371
# Submitted batch job 65372
# Submitted batch job 65373
# Submitted batch job 65374
# Submitted batch job 65375
# Submitted batch job 65376
# Submitted batch job 65377
# Submitted batch job 65378
# Submitted batch job 65379
# Submitted batch job 65380
# Submitted batch job 65381
# Submitted batch job 65382
# Submitted batch job 65383
# Submitted batch job 65384
# Submitted batch job 65385
# Submitted batch job 65386
# Submitted batch job 65387
# Submitted batch job 65388
# Submitted batch job 65389
# Submitted batch job 65390
# Submitted batch job 65391
# Submitted batch job 65392
# Submitted batch job 65393
# Submitted batch job 65394
# Submitted batch job 65395
# Submitted batch job 65396
# Submitted batch job 65397
# Submitted batch job 65398
# Submitted batch job 65399
# Submitted batch job 65400
# Submitted batch job 65401
# Submitted batch job 65402
# Submitted batch job 65403
# Submitted batch job 65404
# Submitted batch job 65405
# Submitted batch job 65406
# Submitted batch job 65407
# Submitted batch job 65408
# Submitted batch job 65409
# Submitted batch job 65410
# Submitted batch job 65411
# Submitted batch job 65412
# Submitted batch job 65413
# Submitted batch job 65414
# Submitted batch job 65415
# Submitted batch job 65416
# Submitted batch job 65417
# Submitted batch job 65418
# Submitted batch job 65419
# Submitted batch job 65420
# Submitted batch job 65421
# Submitted batch job 65422
# Submitted batch job 65423
# Submitted batch job 65424
# Submitted batch job 65425
# Submitted batch job 65426
# Submitted batch job 65427
# Submitted batch job 65428
# Submitted batch job 65429
# Submitted batch job 65430
# Submitted batch job 65431
# Submitted batch job 65432
# Submitted batch job 65433
# Submitted batch job 65434
# Submitted batch job 65435
# Submitted batch job 65436
# Submitted batch job 65437
# Submitted batch job 65438
# Submitted batch job 65439
# Submitted batch job 65440
# Submitted batch job 65441
# Submitted batch job 65442
# Submitted batch job 65443
# Submitted batch job 65444
# Submitted batch job 65445
# Submitted batch job 65446
# Submitted batch job 65447
# Submitted batch job 65448
# Submitted batch job 65449
# Submitted batch job 65450
# Submitted batch job 65451
# Submitted batch job 65452
# Submitted batch job 65453
# Submitted batch job 65454
# Submitted batch job 65455
# Submitted batch job 65456
# Submitted batch job 65457
# Submitted batch job 65458
# Submitted batch job 65459
# Submitted batch job 65460
# Submitted batch job 65461
# Submitted batch job 65462
# Submitted batch job 65463
# Submitted batch job 65464
# Submitted batch job 65465
# Submitted batch job 65466
# Submitted batch job 65467
# Submitted batch job 65468
# Submitted batch job 65469
# Submitted batch job 65470
# Submitted batch job 65471
# Submitted batch job 65472
# Submitted batch job 65473
# Submitted batch job 65474
# Submitted batch job 65475
# Submitted batch job 65476
# Submitted batch job 65477
# Submitted batch job 65478
# Submitted batch job 65479
# Submitted batch job 65480
# Submitted batch job 65481
# Submitted batch job 65482
# Submitted batch job 65483
# Submitted batch job 65484
# Submitted batch job 65485
# Submitted batch job 65486
# Submitted batch job 65487
# Submitted batch job 65488
# Submitted batch job 65489
# Submitted batch job 65490
# Submitted batch job 65491
# Submitted batch job 65492
# Submitted batch job 65493
# Submitted batch job 65494
# Submitted batch job 65495
# Submitted batch job 65496
# Submitted batch job 65497
# Submitted batch job 65498
# Submitted batch job 65499
# Submitted batch job 65500
# Submitted batch job 65501
# Submitted batch job 65502
# Submitted batch job 65503
# Submitted batch job 65504
# Submitted batch job 65505
# Submitted batch job 65506
# Submitted batch job 65507
# Submitted batch job 65508
# Submitted batch job 65509
# Submitted batch job 65510
# Submitted batch job 65511
# Submitted batch job 65512
# Submitted batch job 65513
# Submitted batch job 65514
# Submitted batch job 65515
# Submitted batch job 65516
# Submitted batch job 65517
# Submitted batch job 65518
# Submitted batch job 65519
# Submitted batch job 65520
# Submitted batch job 65521
# Submitted batch job 65522
# Submitted batch job 65523
# Submitted batch job 65524
# Submitted batch job 65525
# Submitted batch job 65526
# Submitted batch job 65527
# Submitted batch job 65528
# Submitted batch job 65529
# Submitted batch job 65530
# Submitted batch job 65531
# Submitted batch job 65532
# Submitted batch job 65533
# Submitted batch job 65534
# Submitted batch job 65535
# Submitted batch job 65536
# Submitted batch job 65537
# Submitted batch job 65538
# Submitted batch job 65539
# Submitted batch job 65540
# Submitted batch job 65541
# Submitted batch job 65542
# Submitted batch job 65543
# Submitted batch job 65544
# Submitted batch job 65545
# Submitted batch job 65546
# Submitted batch job 65547
# Submitted batch job 65548
# Submitted batch job 65549
# Submitted batch job 65550
# Submitted batch job 65551
# Submitted batch job 65552
# Submitted batch job 65553
# Submitted batch job 65554
# Submitted batch job 65555
# Submitted batch job 65556
# Submitted batch job 65557
# Submitted batch job 65558
# Submitted batch job 65559
# Submitted batch job 65560
# Submitted batch job 65561
# Submitted batch job 65562
# Submitted batch job 65563
# Submitted batch job 65564
# Submitted batch job 65565
# Submitted batch job 65566
# Submitted batch job 65567
# Submitted batch job 65568
# Submitted batch job 65569
# Submitted batch job 65570
# Submitted batch job 65571
# Submitted batch job 65572
# Submitted batch job 65573
# Submitted batch job 65574
# Submitted batch job 65575
# Submitted batch job 65576
# Submitted batch job 65577
# Submitted batch job 65578
# Submitted batch job 65579
# Submitted batch job 65580
# Submitted batch job 65581
# Submitted batch job 65582
# Submitted batch job 65583
# Submitted batch job 65584
# Submitted batch job 65585
# Submitted batch job 65586
# Submitted batch job 65587
# Submitted batch job 65588
# Submitted batch job 65589
# Submitted batch job 65590
# Submitted batch job 65591
# Submitted batch job 65592
# Submitted batch job 65593
# Submitted batch job 65594
# Submitted batch job 65595
# Submitted batch job 65596
# Submitted batch job 65597
# Submitted batch job 65598
# Submitted batch job 65599
# Submitted batch job 65600
# Submitted batch job 65601
# Submitted batch job 65602
# Submitted batch job 65603
# Submitted batch job 65604
# Submitted batch job 65605
# Submitted batch job 65606
# Submitted batch job 65607
# Submitted batch job 65608
# Submitted batch job 65609
# Submitted batch job 65610
# Submitted batch job 65611
# Submitted batch job 65612
# Submitted batch job 65613
# Submitted batch job 65614
# Submitted batch job 65615
# Submitted batch job 65616
# Submitted batch job 65617
# Submitted batch job 65618
# Submitted batch job 65619
# Submitted batch job 65620
# Submitted batch job 65621
# Submitted batch job 65622
# Submitted batch job 65623
# Submitted batch job 65624
# Submitted batch job 65625
# Submitted batch job 65626
# Submitted batch job 65627
# Submitted batch job 65628
# Submitted batch job 65629
# Submitted batch job 65630
# Submitted batch job 65631
# Submitted batch job 65632
# Submitted batch job 65633
# Submitted batch job 65634
# Submitted batch job 65635
# Submitted batch job 65636
# Submitted batch job 65637
# Submitted batch job 65638
# Submitted batch job 65639
# Submitted batch job 65640
# Submitted batch job 65641
# Submitted batch job 65642
# Submitted batch job 65643
# Submitted batch job 65644
# Submitted batch job 65645
# Submitted batch job 65646
# Submitted batch job 65647
# Submitted batch job 65648
# Submitted batch job 65649
# Submitted batch job 65650
# Submitted batch job 65651
# Submitted batch job 65652
# Submitted batch job 65653
# Submitted batch job 65654
# Submitted batch job 65655
# Submitted batch job 65656
# Submitted batch job 65657
# Submitted batch job 65658
# Submitted batch job 65659
# Submitted batch job 65660
# Submitted batch job 65661
# Submitted batch job 65662
# Submitted batch job 65663
# Submitted batch job 65664
# Submitted batch job 65665
# Submitted batch job 65666
# Submitted batch job 65667
# Submitted batch job 65668
# Submitted batch job 65669
# Submitted batch job 65670
# Submitted batch job 65671
# Submitted batch job 65672
# Submitted batch job 65673
# Submitted batch job 65674
# Submitted batch job 65675
# Submitted batch job 65676
# Submitted batch job 65677
# Submitted batch job 65678
# Submitted batch job 65679
# Submitted batch job 65680
# Submitted batch job 65681
# Submitted batch job 65682
# Submitted batch job 65683
# Submitted batch job 65684
# Submitted batch job 65685
# Submitted batch job 65686
# Submitted batch job 65687
# Submitted batch job 65688
# Submitted batch job 65689
# Submitted batch job 65690
# Submitted batch job 65691
# Submitted batch job 65692
# Submitted batch job 65693
# Submitted batch job 65694
# Submitted batch job 65695
# Submitted batch job 65696
# Submitted batch job 65697
# Submitted batch job 65698
# Submitted batch job 65699
# Submitted batch job 65700
# Submitted batch job 65701
# Submitted batch job 65702
# Submitted batch job 65703
# Submitted batch job 65704
# Submitted batch job 65705
# Submitted batch job 65706
# Submitted batch job 65707
# Submitted batch job 65708
# Submitted batch job 65709
# Submitted batch job 65710
# Submitted batch job 65711
# Submitted batch job 65712
# Submitted batch job 65713
# Submitted batch job 65714
# Submitted batch job 65715
# Submitted batch job 65716
# Submitted batch job 65717
# Submitted batch job 65718
# Submitted batch job 65719
# Submitted batch job 65720
# Submitted batch job 65721
# Submitted batch job 65722
# Submitted batch job 65723
# Submitted batch job 65724
# Submitted batch job 65725
# Submitted batch job 65726
# Submitted batch job 65727
# Submitted batch job 65728
# Submitted batch job 65729
# Submitted batch job 65730
# Submitted batch job 65731
# Submitted batch job 65732
# Submitted batch job 65733
# Submitted batch job 65734
# Submitted batch job 65735
# Submitted batch job 65736
# Submitted batch job 65737
# Submitted batch job 65738
# Submitted batch job 65739
# Submitted batch job 65740
# Submitted batch job 65741
# Submitted batch job 65742
# Submitted batch job 65743
# Submitted batch job 65744
# Submitted batch job 65745
# Submitted batch job 65746
# Submitted batch job 65747
# Submitted batch job 65748
# Submitted batch job 65749
# Submitted batch job 65750
# Submitted batch job 65751
# Submitted batch job 65752
# Submitted batch job 65753
# Submitted batch job 65754
# Submitted batch job 65755
# Submitted batch job 65756
# Submitted batch job 65757
# Submitted batch job 65758
# Submitted batch job 65759
# Submitted batch job 65760
# Submitted batch job 65761
# Submitted batch job 65762
# Submitted batch job 65763
# Submitted batch job 65764
# Submitted batch job 65765
# Submitted batch job 65766
# Submitted batch job 65767
# Submitted batch job 65768
# Submitted batch job 65769
# Submitted batch job 65770
# Submitted batch job 65771
# Submitted batch job 65772
# Submitted batch job 65773
# Submitted batch job 65774
# Submitted batch job 65775
# Submitted batch job 65776
# Submitted batch job 65777
# Submitted batch job 65778
# Submitted batch job 65779
# Submitted batch job 65780
# Submitted batch job 65781
# Submitted batch job 65782
# Submitted batch job 65783
# Submitted batch job 65784
# Submitted batch job 65785
# Submitted batch job 65786
# Submitted batch job 65787
# Submitted batch job 65788
# Submitted batch job 65789
# Submitted batch job 65790
# Submitted batch job 65791
# Submitted batch job 65792
# Submitted batch job 65793
# Submitted batch job 65794
# Submitted batch job 65795
# Submitted batch job 65796
# Submitted batch job 65797
# Submitted batch job 65798
# Submitted batch job 65799
# Submitted batch job 65800
# Submitted batch job 65801
# Submitted batch job 65802
# Submitted batch job 65803
# Submitted batch job 65804
# Submitted batch job 65805
# Submitted batch job 65806
# Submitted batch job 65807
# Submitted batch job 65808
# Submitted batch job 65809
# Submitted batch job 65810
# Submitted batch job 65811
# Submitted batch job 65812
# Submitted batch job 65813
# Submitted batch job 65814
# Submitted batch job 65815
# Submitted batch job 65816
# Submitted batch job 65817
# Submitted batch job 65818
# Submitted batch job 65819
# Submitted batch job 65820
# Submitted batch job 65821
# Submitted batch job 65822
# Submitted batch job 65823
# Submitted batch job 65824
# Submitted batch job 65825
# Submitted batch job 65826
# Submitted batch job 65827
# Submitted batch job 65828
# Submitted batch job 65829
# Submitted batch job 65830
# Submitted batch job 65831
# Submitted batch job 65832
# Submitted batch job 65833
# Submitted batch job 65834
# Submitted batch job 65835
# Submitted batch job 65836
# Submitted batch job 65837
# Submitted batch job 65838
# Submitted batch job 65839
# Submitted batch job 65840
# Submitted batch job 65841
# Submitted batch job 65842
# Submitted batch job 65843
# Submitted batch job 65844
# Submitted batch job 65845
# Submitted batch job 65846
# Submitted batch job 65847
# Submitted batch job 65848
# Submitted batch job 65849
# Submitted batch job 65850
# Submitted batch job 65851
# Submitted batch job 65852
# Submitted batch job 65853
# Submitted batch job 65854
# Submitted batch job 65855
# Submitted batch job 65856
# Submitted batch job 65857
# Submitted batch job 65858
# Submitted batch job 65859
# Submitted batch job 65860
# Submitted batch job 65861
# Submitted batch job 65862
# Submitted batch job 65863
# Submitted batch job 65864
# Submitted batch job 65865
# Submitted batch job 65866
# Submitted batch job 65867
# Submitted batch job 65868
# Submitted batch job 65869
# Submitted batch job 65870
# Submitted batch job 65871
# Submitted batch job 65872
# Submitted batch job 65873
# Submitted batch job 65874
# Submitted batch job 65875
# Submitted batch job 65876
# Submitted batch job 65877
# Submitted batch job 65878
# Submitted batch job 65879
# Submitted batch job 65880
# Submitted batch job 65881
# Submitted batch job 65882
# Submitted batch job 65883
# Submitted batch job 65884
# Submitted batch job 65885
# Submitted batch job 65886
# Submitted batch job 65887
# Submitted batch job 65888
# Submitted batch job 65889
# Submitted batch job 65890
# Submitted batch job 65891
# Submitted batch job 65892
# Submitted batch job 65893
# Submitted batch job 65894
# Submitted batch job 65895
# Submitted batch job 65896
# Submitted batch job 65897
# Submitted batch job 65898
# Submitted batch job 65899
# Submitted batch job 65900
# Submitted batch job 65901
# Submitted batch job 65902
# Submitted batch job 65903
# Submitted batch job 65904
# Submitted batch job 65905
# Submitted batch job 65906
# Submitted batch job 65907
# Submitted batch job 65908
# Submitted batch job 65909
# Submitted batch job 65910
# Submitted batch job 65911
# Submitted batch job 65912
# Submitted batch job 65913
# Submitted batch job 65914
# Submitted batch job 65915
# Submitted batch job 65916
# Submitted batch job 65917
# Submitted batch job 65918
# Submitted batch job 65919
# Submitted batch job 65920
# Submitted batch job 65921
# Submitted batch job 65922
# Submitted batch job 65923
# Submitted batch job 65924
# Submitted batch job 65925
# Submitted batch job 65926
# Submitted batch job 65927
# Submitted batch job 65928
# Submitted batch job 65929
# Submitted batch job 65930
# Submitted batch job 65931
# Submitted batch job 65932
# Submitted batch job 65933
# Submitted batch job 65934
# Submitted batch job 65935
# Submitted batch job 65936
# Submitted batch job 65937

# %%
files = os.listdir('../baypass_lastgen/individual_gfiles_last_gen/')
loci_names = [file for file in files if 'loci' in file]

# %%
for split in range(len(samples)):
    print(split)
    print(len(os.listdir(f'results/split_{split}')))
# Out:
# 0
# 203
# 1
# 202
# 2
# 202
# 3
# 202
# 4
# 202
# 5
# 202
# 6
# 202
# 7
# 202
# 8
# 202
# 9
# 202
# 10
# 202
# 11
# 202
# 12
# 202
# 13
# 202
# 14
# 202
# 15
# 202
# 16
# 202
# 17
# 202
# 18
# 202
# 19
# 202
# 20
# 202
# 21
# 202
# 22
# 202
# 23
# 202
# 24
# 202
# 25
# 202
# 26
# 202
# 27
# 202
# 28
# 202
# 29
# 202
# 30
# 202

# %%
for split in range(len(samples_fake)):
    print(split)
    partitions_r = {}
    for i in range(len(partitions)):  # /baypass_first_gen/individual_gfiles/
        pickle_file_path = f'../baypass_first_gen/individual_gfiles/loci_partition_{i}'
        with open(pickle_file_path, 'rb') as file:
            loci_f = pickle.load(file)
        results = pd.read_csv(f'results_sites_unseen/split_{split}/partition{i}.csv')
        results['snp_id'] = loci_f
        partitions_r[i] = results
    results = pd.concat(partitions_r).reset_index(drop=True)
    results.to_csv(f'results_sites_unseen/split_{split}/binomial_reg_results_first_gen_sites_unseen.csv',index=None)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
pd.read_csv(f'results_sites_unseen/split_{split}/binomial_reg_results_first_gen_sites_unseen.csv')
# Out:
#                47     slope        pvalue  intercept      snp_id
# 0        0.271129  0.002634  8.171630e-01  -0.988079       1_346
# 1        0.075197  0.074634  8.585182e-05  -2.486135       1_353
# 2        0.097985 -0.022623  1.856125e-01  -2.226889       1_363
# 3        0.076062  0.377930  7.818571e-97  -2.378932       1_395
# 4        0.076062  0.377930  7.818571e-97  -2.378932       1_396
# ...           ...       ...           ...        ...         ...
# 1054569  0.812567 -0.206419  6.118108e-59   1.402234  5_26975078
# 1054570  0.077901  0.056934  2.389608e-03  -2.453414  5_26975121
# 1054571  0.077901  0.056934  2.389608e-03  -2.453414  5_26975148
# 1054572  0.462689  0.007647  4.516182e-01  -0.147132  5_26975272
# 1054573  0.175106 -0.056704  2.368049e-05  -1.567595  5_26975288
#
# [1054574 rows x 5 columns]
