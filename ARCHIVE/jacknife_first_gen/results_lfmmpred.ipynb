# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import os
import pickle
import dask.dataframe as dd
import seaborn as sns
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import subprocess
import random
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

import numpy as np
import cvxpy as cp

# %%
all_ef = pd.DataFrame()
for split_number in range(31):
    output_file_ef = f'/carnegie/nobackup/scratch/tbellagio/gea_grene-net/jacknife_first_gen/split_number_{split_number}/delta_p/results_ef.csv' 
    ef = pd.read_csv(output_file_ef)
    ef['site'] = ef['Unnamed: 0'].str.split('_').str[0]
    all_ef = pd.concat([all_ef,ef])

# %%
metric = 'sp_correlation'
#all_ef = all_ef.groupby(['sample','site'])['r2'].mean().reset_index()

medians = all_ef.groupby('site')[metric].median().sort_values()

# Set the size of the plot
plt.figure(figsize=(12, 6))  # You can adjust the width and height as needed

# Create the plot, ordering by median metric
# Use 'scale' to adjust the width of violins; options are 'area', 'count', or 'width'
sns.violinplot(data=all_ef, y=metric, x='site', order=medians.index, color = 'Grey')

# Draw a horizontal line at y=0
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable
plt.ylim(-0.4, 1.1)
plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)

# Optionally, add labels or a title
plt.title('LFMM Spearman\'s corr pred vs real delta ecotype frequency')
plt.xlabel('Site')
plt.ylabel('Rho')
#plt.savefig('LFMM_sp.png')
# Show the plot
plt.show()

# %%
metric = 'r_squared'
#all_ef = all_ef.groupby(['sample','site'])['r2'].mean().reset_index()

medians = all_ef.groupby('site')[metric].median().sort_values()

# Set the size of the plot
plt.figure(figsize=(12, 6))  # You can adjust the width and height as needed

# Create the plot, ordering by median metric
# Use 'scale' to adjust the width of violins; options are 'area', 'count', or 'width'
sns.violinplot(data=all_ef, y=metric, x='site', order=medians.index, color = 'Grey')

# Draw a horizontal line at y=0
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable
plt.ylim(-0.4, 1.1)
plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)

# Optionally, add labels or a title
plt.title('LFMM Spearman\'s corr pred vs real delta ecotype frequency')
plt.xlabel('Site')
plt.ylabel('Rho')
#plt.savefig('LFMM_sp.png')
# Show the plot
plt.show()

# %%
metric = 'pearsonr'
#all_ef = all_ef.groupby(['sample','site'])['r2'].mean().reset_index()

medians = all_ef.groupby('site')[metric].median().sort_values()

# Set the size of the plot
plt.figure(figsize=(12, 6))  # You can adjust the width and height as needed

# Create the plot, ordering by median metric
# Use 'scale' to adjust the width of violins; options are 'area', 'count', or 'width'
sns.violinplot(data=all_ef, y=metric, x='site', order=medians.index, color = 'Grey')

# Draw a horizontal line at y=0
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable
plt.ylim(-0.4, 1.1)
plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)

# Optionally, add labels or a title
plt.title('LFMM Spearman\'s corr pred vs real delta ecotype frequency')
plt.xlabel('Site')
plt.ylabel('Rho')
#plt.savefig('LFMM_sp.png')
# Show the plot
plt.show()

# %%
all_af = pd.DataFrame()
for split_number in range(31):
    output_file_af = f'/carnegie/nobackup/scratch/tbellagio/gea_grene-net/jacknife_first_gen/split_number_{split_number}/delta_p/results_af_sw.csv' 
    af = pd.read_csv(output_file_af)
    af['site'] = af['Unnamed: 0'].str.split('_').str[0]
    all_af = pd.concat([all_af,af])

# %%
metric = 'sp_correlation'
#all_af = all_af.groupby(['sample','site'])['r2'].mean().reset_index()

medians = all_af.groupby('site')[metric].median().sort_values()

# Set the size of the plot
plt.figure(figsize=(12, 6))  # You can adjust the width and height as needed

# Create the plot, ordering by median metric
# Use 'scale' to adjust the width of violins; options are 'area', 'count', or 'width'
sns.violinplot(data=all_af, y=metric, x='site', order=medians.index, color = 'Grey')

# Draw a horizontal line at y=0
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable

plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)

# Optionally, add labels or a title
plt.title('LFMM Spearman\'s corr pred vs real delta ecotype frequency')
plt.xlabel('Site')
plt.ylabel('Rho')
#plt.savefig('LFMM_sp.png')
# Show the plot
plt.show()

# %%
metric = 'pearsonr'
#all_af = all_af.groupby(['sample','site'])['r2'].mean().reset_index()

medians = all_af.groupby('site')[metric].median().sort_values()

# Set the size of the plot
plt.figure(figsize=(12, 6))  # You can adjust the width and height as needed

# Create the plot, ordering by median metric
# Use 'scale' to adjust the width of violins; options are 'area', 'count', or 'width'
sns.violinplot(data=all_af, y=metric, x='site', order=medians.index, color = 'Grey')

# Draw a horizontal line at y=0
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable
plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)

# Optionally, add labels or a title
plt.title('LFMM Spearman\'s corr pred vs real delta ecotype frequency')
plt.xlabel('Site')
plt.ylabel('Rho')
#plt.savefig('LFMM_sp.png')
# Show the plot
plt.show()

# %%
metric = 'r_squared'
#all_af = all_af.groupby(['sample','site'])['r2'].mean().reset_index()

medians = all_af.groupby('site')[metric].median().sort_values()

# Set the size of the plot
plt.figure(figsize=(12, 6))  # You can adjust the width and height as needed

# Create the plot, ordering by median metric
# Use 'scale' to adjust the width of violins; options are 'area', 'count', or 'width'
sns.violinplot(data=all_af, y=metric, x='site', order=medians.index, color = 'Grey')

# Draw a horizontal line at y=0
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable
plt.ylim(-0.4, 1.1)
plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)

# Optionally, add labels or a title
plt.title('LFMM Spearman\'s corr pred vs real delta ecotype frequency')
plt.xlabel('Site')
plt.ylabel('Rho')
#plt.savefig('LFMM_sp.png')
# Show the plot
plt.show()

# %%
for split_number in range(100):
    output_file_ef_p1overp0 = f'/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_{split_number}/delta_p/sp_corr_p1overp0.csv' 
    p1overp0 = pd.read_csv(output_file_ef_p1overp0)
    output_file_ef_deltap = f'/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_{split_number}/delta_p/sp_corr_deltap.csv' 
    deltap = pd.read_csv(output_file_ef_deltap)

# %%
for split_number in range(20):
    output_file_ef_p1overp0 = f'/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_{split_number}/delta_p/sp_corr_p1overp0.csv' 
    p1overp0 = pd.read_csv(output_file_ef_p1overp0).drop('Unnamed: 0',axis=1)
    p1overp0.columns = ['samples', 'p1overp0']
    p1overp0 = p1overp0.set_index('samples')
    
    output_file_ef_deltap = f'/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_{split_number}/delta_p/sp_corr_deltap.csv' 
    deltap = pd.read_csv(output_file_ef_deltap).drop('Unnamed: 0',axis=1)
    deltap.columns = ['samples', 'deltap']
    deltap = deltap.set_index('samples')
    
    both = pd.concat([p1overp0, deltap], axis=1)
    sns.scatterplot(both, x = 'p1overp0', y ='deltap' )
    plt.ylim(-0.5, 1)
    plt.xlim(-0.5, 1)

# %%
# Out:
# (-0.5, 1.0)

# %%
p1overp0
# Out:
#    samples  p1overp0
# 0      2_8  0.066236
# 1      2_9  0.037760
# 2     2_11  0.072362
# 3     2_12  0.001529
# 4      2_5 -0.071169
# ..     ...       ...
# 61    54_8  0.058543
# 62    54_9  0.046493
# 63   54_10  0.085975
# 64   54_11  0.054595
# 65   54_12  0.015794
#
# [66 rows x 2 columns]

# %%
deltap
# Out:
#     Unnamed: 0 sample        r2
# 0            0    2_8  0.129603
# 1            1    2_9  0.061857
# 2            2   2_11  0.209493
# 3            3   2_12  0.172397
# 4            4    2_5  0.346678
# ..         ...    ...       ...
# 61          61   54_8  0.097769
# 62          62   54_9  0.248249
# 63          63  54_10  0.212651
# 64          64  54_11  0.286553
# 65          65  54_12  0.204801
#
# [66 rows x 3 columns]

# %%
output_file_ef_p1overp0
# Out:
# '/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_99/delta_p/sp_corr_p1overp0.csv'

# %%
all_af = pd.DataFrame()
for split_number in range(100):
    output_file_af = f'/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_{split_number}/delta_p/r2_pred_allele_freq.csv' 
    af = pd.read_csv(output_file_af)
    af['site'] = af['sample'].str.split('_').str[0]
    all_af = pd.concat([all_af,af])

# %%
all_af = all_af.groupby(['sample','site'])['r2'].mean().reset_index()

# %%
medians = all_af.groupby('site')['r2'].median().sort_values()
plt.figure(figsize=(12, 6)) 
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable

sns.violinplot(data=all_af, y='r2', x='site', order=medians.index, alpha = 0.5, color='Grey')
plt.title('LFMM R2 for allele frequency')

plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)  # Remove the right spine

# %%
medians = all_af.groupby('site')['r2'].median().sort_values()
plt.figure(figsize=(12, 6)) 
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable

sns.scatterplot(data=all_af, y='r2', x='site', alpha = 0.5, color='Grey')
plt.title('LFMM R2 for allele frequency')
plt.ylim(0, 1.1)
plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)  # Remove the right spine

# %%
all_af = pd.DataFrame()
for split_number in range(100):
    output_file_af = f'/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_{split_number}/delta_p/pearson_af.csv' 
    af = pd.read_csv(output_file_af)
    af['site'] = af['sample'].str.split('_').str[0]
    all_af = pd.concat([all_af,af])

# %%
all_af = all_af.groupby(['sample','site'])['r2'].mean().reset_index()

# %%
medians = all_af.groupby('site')['r2'].median().sort_values()
plt.figure(figsize=(12, 6)) 
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable

sns.violinplot(data=all_af, y='r2', x='site', order=medians.index, alpha = 0.5, color='Grey')
plt.title('LFMM Pearson corr for allele frequency')
#plt.ylim(-0.15, 1.1)
plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)

# %%
all_ef = all_ef[['sample', 'r2', 'site', 'n_snps']]

# %%
all_ef.columns = ['sample', 'sp_corr', 'site', 'n_snps_used']

# %%
all_ef.to_csv('sp_corr_LFMM.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

medians = all_ef.groupby('site')['r2'].median().sort_values()

# Set the size of the plot
plt.figure(figsize=(15, 6))  # You can adjust the width and height as needed

# Create the plot, ordering by median 'r2'
# Use 'scale' to adjust the width of violins; options are 'area', 'count', or 'width'
violin_plot = sns.violinplot(data=all_ef, y='r2', x='site', order=medians.index, color='Grey', hue='sample',
                             )  # `split=True` for side by side comparison within each site

# Draw a horizontal line at y=0
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable
plt.ylim(-0.4, 1.1)
plt.grid(axis='y')

# Remove the legend
violin_plot.legend_.remove()

# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)

# Optionally, add labels or a title
plt.title('LFMM Spearman\'s corr pred vs real ecotype frequency')
plt.xlabel('Rho')
plt.ylabel('r2')

# Increase space between groups
#plt.subplots_adjust(wspace=0.5)  # Adjust the width spacing between subplots

# Show the plot
plt.show()

# %%
all_ef
# Out:
#      sample        r2    r2_fit site  n_snps
# 0     4_1_4  0.197418  0.999963    4     212
# 1     4_3_1  0.201783  0.999963    4     212
# 2     4_3_2  0.105397  0.999963    4     212
# 3     4_3_3  0.067317  0.999963    4     212
# 4     4_3_5  0.159185  0.999963    4     212
# ..      ...       ...       ...  ...     ...
# 61   54_3_8  0.187831  1.000000   54     118
# 62   54_3_9  0.163729  1.000000   54     118
# 63  54_3_10  0.166399  1.000000   54     118
# 64  54_3_11  0.171721  1.000000   54     118
# 65  54_3_12  0.104210  1.000000   54     118
#
# [6861 rows x 5 columns]

# %%
sns.scatterplot(all_ef, x = 'n_snps', y = 'r2', alpha =0.5)
# Out:
# <Axes: xlabel='n_snps', ylabel='r2'>

# %%
medians = all_ef.groupby('site')['r2'].median().sort_values()

# Set the size of the plot
plt.figure(figsize=(12, 6))  # You can adjust the width and height as needed

# Create the plot, ordering by median 'r2'
# Use 'scale' to adjust the width of violins; options are 'area', 'count', or 'width'
sns.violinplot(data=all_ef, y='r2', x='site', order=medians.index, color = 'Grey')

# Draw a horizontal line at y=0
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable
plt.ylim(-0.4, 1.1)
plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)

# Optionally, add labels or a title
plt.title('LFMM Spearman\'s corr pred vs real ecotype frequency')
plt.xlabel('Rho')
plt.ylabel('r2')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(12, 6)) 
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable

sns.stripplot(data=all_ef, y='r2', x='site', order=medians.index, alpha = 0.5, color='Grey')
plt.title('R2 for ecotype frequency prediction')
plt.xlabel('Site')
plt.ylabel('r2')
plt.ylim(-0.15, 1.1)
plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)

# %%
all_af = pd.DataFrame()
for split_number in range(76):
    output_file_af = f'/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_{split_number}/r2_pred_allele_freq_wmean.csv' 
    af = pd.read_csv(output_file_af)
    af['site'] = af['sample'].str.split('_').str[0]
    all_af = pd.concat([all_af,af])

# %%
medians = all_af.groupby('site')['r2'].median().sort_values()

# Set the size of the plot
plt.figure(figsize=(12, 6))  # You can adjust the width and height as needed

# Create the plot, ordering by median 'r2'
# Use 'scale' to adjust the width of violins; options are 'area', 'count', or 'width'
sns.violinplot(data=all_af, y='r2', x='site', order=medians.index, color='Grey')

# Draw a horizontal line at y=0
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable

# Optionally, add labels or a title
plt.title('R2 for allele frequency')
plt.xlabel('Site')
plt.ylabel('r2')
plt.ylim(-0.15, 1.1)
plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)  # Remove the right spine
# Show the plot
plt.show()

# %%
medians = all_af.groupby('site')['r2'].median().sort_values()
plt.figure(figsize=(12, 6)) 
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable

sns.stripplot(data=all_af, y='r2', x='site', order=medians.index, alpha = 0.5, color='Grey')
plt.title('R2 for allele frequency')
plt.ylim(-0.15, 1.1)
plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)  # Remove the right spine

# %%
all_ef = pd.DataFrame()
for split_number in range(76):
    output_file_ef = f'/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_{split_number}/r2_pred_ecotype_freq_wmean_clumped.csv' 
    ef = pd.read_csv(output_file_ef)
    ef['site'] = ef['sample'].str.split('_').str[0]
    all_ef = pd.concat([all_ef,ef])

# %%
medians = all_ef.groupby('site')['r2'].median().sort_values()

# Set the size of the plot
plt.figure(figsize=(12, 6))  # You can adjust the width and height as needed

# Create the plot, ordering by median 'r2'
# Use 'scale' to adjust the width of violins; options are 'area', 'count', or 'width'
sns.violinplot(data=all_ef, y='r2', x='site', order=medians.index)

# Draw a horizontal line at y=0
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable
plt.ylim(-0.15, 1.1)
plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)

# Optionally, add labels or a title
plt.title('R2 for ecotype frequency')
plt.xlabel('Site')
plt.ylabel('r2')

# Show the plot
plt.show()

# %%
plt.figure(figsize=(12, 6)) 
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable

sns.stripplot(data=all_ef, y='r2', x='site', order=medians.index, alpha = 0.5, color='Grey')
plt.title('R2 for ecotype frequency prediction')
plt.xlabel('Site')
plt.ylabel('r2')
plt.ylim(-0.15, 1.1)
plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)

# %%
all_af = pd.DataFrame()
for split_number in range(76):
    output_file_af = f'/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_{split_number}/r2_pred_allele_freq_wmean_clumped.csv' 
    af = pd.read_csv(output_file_af)
    af['site'] = af['sample'].str.split('_').str[0]
    all_af = pd.concat([all_af,af])

# %%
medians = all_af.groupby('site')['r2'].median().sort_values()

# Set the size of the plot
plt.figure(figsize=(12, 6))  # You can adjust the width and height as needed

# Create the plot, ordering by median 'r2'
# Use 'scale' to adjust the width of violins; options are 'area', 'count', or 'width'
sns.violinplot(data=all_af, y='r2', x='site', order=medians.index, color='Grey')

# Draw a horizontal line at y=0
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable

# Optionally, add labels or a title
plt.title('R2 for allele frequency')
plt.xlabel('Site')
plt.ylabel('r2')
plt.ylim(-0.15, 1.1)
plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)  # Remove the right spine
# Show the plot
plt.show()

# %%
medians = all_af.groupby('site')['r2'].median().sort_values()
plt.figure(figsize=(12, 6)) 
plt.axhline(0, color='grey', linestyle='--')  # Color and style are adjustable

sns.stripplot(data=all_af, y='r2', x='site', order=medians.index, alpha = 0.5, color='Grey')
plt.title('R2 for allele frequency')
plt.ylim(-0.15, 1.1)
plt.grid(axis='y')
# Remove top and right spines
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)  # Remove the right spine

# %%
pearsonr(y, f)
# Out:
# (0.9929674489269135, 0.0007072037254556302)

# %%
from sklearn.metrics import r2_score
from scipy.stats import pearsonr
import numpy as np

# True values
y = np.array([10, 20, 30, 50, 90])

# Predictions
f = np.array([20, 40, 60, 75, 135])

# Calculate r-squared
r2 = r2_score(y, f)
print('R-Squared:', r2)
# Output: -0.012

corr = pearsonr(y, f)[0]
print('Pearson Correlation:', corr)
# Output: 0.992

# Here's a way to interpret: r2 is equivalent to the following

mean_squared_error = lambda y, f: np.mean((y-f)**2)
r2_eq = 1-mean_squared_error(y, f)/mean_squared_error(y, [y.mean()]*len(y))
print(
    'R-Squared (from equation):',
    r2_eq
)
# Output: -0.0124

# Hence it is negative as MSE given f is higher than MSE given y.mean() as f
# Out:
# R-Squared: -0.012499999999999956
# Pearson Correlation: 0.9929674489269135
# R-Squared (from equation): -0.012499999999999956

# %%
sns.scatterplot(x = y , y = f)
# Out:
# <Axes: >

# %%
pearsonr(y, f)
# Out:
# (0.9929674489269135, 0.0007072037254556302)

# %%
y
# Out:
# array([10, 20, 30, 50, 90])

# %%
f
# Out:
# array([ 20,  40,  60,  75, 135])
