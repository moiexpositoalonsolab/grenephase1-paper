# %%
# args[2] will be the space-separated train samples
train_samples <- '4 27 43 25 26 28 60 49 46 24 1 55 9 45 12 42 13 33 23 37 57 10 32 48 53'

# Remove the outer brackets and quotes
train_samples <- gsub("\\[|\\]|'", "", train_samples)

# Split the string into a vector of strings
train_samples_vector <- strsplit(train_samples, " ")[[1]]

# Trim any leading or trailing whitespace from each element
train_samples_vector <- trimws(train_samples_vector)

print(train_samples_vector)
# Out:
#  [1] "4"  "27" "43" "25" "26" "28" "60" "49" "46" "24" "1"  "55" "9"  "45" "12"
# [16] "42" "13" "33" "23" "37" "57" "10" "32" "48" "53"

# %%
train_samples_vector
# Out:
#  [1] "4"  "27" "43" "25" "26" "28" "60" "49" "46" "24" "1"  "55" "9"  "45" "12"
# [16] "42" "13" "33" "23" "37" "57" "10" "32" "48" "53"

# %%
strsplit(train_samples, " ")
# Out:
# [[1]]
#  [1] "4"  "27" "43" "25" "26" "28" "60" "49" "46" "24" "1"  "55" "9"  "45" "12"
# [16] "42" "13" "33" "23" "37" "57" "10" "32" "48" "53"

# %%
split_number <- 0

# %%
delta_p_file = '/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/delta_p_mean.csv'

# %%
allele_freq <- fread(delta_p_file, sep = ',', header = TRUE, check.names = FALSE)
# Out:
# Error in fread(delta_p_file, sep = ",", header = TRUE, check.names = FALSE): could not find function "fread"
# Traceback:

# %%
path_all_af = '/carnegie/nobackup/scratch/tbellagio/gea_grene-net/allele_freq_partitions'
results_dir = sprintf('/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_%d', split_number)

k <- as.integer(readLines(sprintf('%s/num_components.txt', results_dir)))
env <- read.csv(sprintf('%s/environment_lea.csv', results_dir), header = TRUE, colClasses = "numeric")

# %%
install.packages('data.table')

# %%
library('data.table')
# Out:
# Error in library("data.table"): there is no package called ‘data.table’
# Traceback:
#
# 1. library("data.table")

# %%
path_all_af_indexed = '/carnegie/nobackup/scratch/tbellagio/gea_grene-net/baypass_terminal/merged_hapFIRE_allele_frequency_indexed.csv'

# %%
# Read only the specified columns
allele_freq <- fread(path_all_af_indexed, select = train_samples_vector, sep = ',', header = TRUE, check.names = FALSE)
# Out:
# Error in fread(path_ldp_afpath_all_af_indexed, select = train_samples_vector): could not find function "fread"
# Traceback:

# %%
zscores = c(0.2,0.1)

# %%
notadj_pvalues <- pchisq((zscores^2), df = 1, lower.tail = FALSE)

# %%
notadj_pvalues
# Out:
# [1] 0.8414806 0.9203443

# %%
basename(path_ldp_af)
# Out:
# [1] "merged_hapFIRE_allele_frequency_LDpruned.txt"

# %%
k
# Out:
# [1] 47

# %%
results_dir = sprintf('/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_%d', split_number)

k <- as.integer(readLines(sprintf('%s/num_components.txt', results_dir)))
# Out:
# Warning message in readLines(sprintf("%s/num_components.txt", results_dir)):
# “incomplete final line found on '/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_0/num_components.txt'”

# %%
train_samples_vector = c('1_2_2',
  '1_2_3',
  '1_3_1',
  '1_3_4',
  '1_3_5',
  '1_3_6',
  '37_1_5',
  '37_1_6',
  '37_1_7',
  '37_1_8',
  '37_1_9',
  '37_1_10',
  '37_1_11',
  '37_1_12',
  '42_1_2',
  '42_1_12',
  '42_2_11',
  '42_3_1',
  '42_3_3',
  '42_3_4',
  '42_3_5',
  '42_3_6',
  '42_3_7',
  '42_3_8',
  '42_3_9',
  '42_3_10',
  '43_1_3',
  '43_1_10',
  '43_2_1',
  '43_3_2',
  '43_3_4',
  '43_3_5',
  '43_3_6',
  '43_3_7',
  '43_3_8',
  '43_3_9',
  '43_3_11',
  '43_3_12',
  '45_2_3',
  '45_2_7',
  '45_3_1',
  '45_3_2',
  '45_3_4',
  '45_3_5',
  '45_3_6',
  '45_3_8',
  '45_3_9',
  '45_3_10',
  '45_3_11',
  '45_3_12',
  '46_3_1',
  '46_3_2',
  '46_3_3',
  '46_3_4',
  '46_3_5',
  '46_3_6',
  '46_3_7',
  '46_3_8',
  '46_3_9',
  '46_3_10',
  '46_3_11',
  '46_3_12',
  '49_2_1',
  '49_2_2',
  '49_2_3',
  '49_2_4',
  '49_2_5',
  '49_2_6',
  '49_2_7',
  '49_2_8',
  '49_2_9',
  '49_2_10',
  '49_2_11',
  '49_2_12',
  '53_3_1',
  '53_3_2',
  '53_3_3',
  '53_3_4',
  '53_3_5',
  '53_3_6',
  '53_3_7',
  '53_3_8',
  '53_3_9',
  '53_3_10',
  '53_3_11',
  '53_3_12',
  '54_3_1',
  '54_3_2',
  '54_3_3',
  '54_3_4',
  '54_3_5',
  '54_3_6',
  '54_3_7',
  '54_3_8',
  '54_3_9',
  '54_3_10',
  '54_3_11',
  '54_3_12',
  '60_1_1',
  '60_1_2',
  '60_1_3',
  '60_1_4',
  '60_1_5',
  '60_1_6',
  '60_1_7',
  '60_1_8',
  '60_1_9',
  '60_1_10',
  '60_1_11',
  '60_1_12')

# %%
split_number = 0

# %%
library("LEA")
library("dplyr")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
path_ldp_af = '/carnegie/nobackup/scratch/xwu/grenet/merged_frequency/merged_hapFIRE_allele_frequency_LDpruned.txt'
results_dir = sprintf('/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_%d', split_number)

k <- as.integer(readLines(sprintf('%s/num_components.txt', results_dir)))
env <- read.csv(sprintf('%s/environment_lea.csv', results_dir), header = TRUE, colClasses = "numeric")
rownames(env) <- NULL
colnames(env) <- NULL
env <- as.matrix(env)


file_name <- basename(path_ldp_af)
output_file_pvalue <- paste0(results_dir, "/pvalues.csv")
output_file_zscores <- paste0(results_dir, "/zscores.csv")
output_file_gif <- paste0(results_dir, "/gif.csv")
output_file_qvalue = paste0(results_dir, "/qvalues.csv")


allele_freq <- read.table(path_ldp_af, sep = '\t', header = TRUE, check.names = FALSE)
allele_freq <- allele_freq[, train_samples_vector]  # Use dynamic columns
colnames(allele_freq) <- NULL
allele_freq <- t(as.matrix(allele_freq))

mod2 <- lfmm2(input = allele_freq, env = env, K = k)
pv <- lfmm2.test(object = mod2, input = allele_freq, env = env)

p_values <- pv$pvalues
zscores <- pv$zscores
gif <- pv$gif

write.csv(p_values, file = output_file_pvalue)
write.csv(zscores, file = output_file_zscores)
write.csv(gif, file = output_file_gif)

##calculate qvalues 
## gif has already been conducted 
p_values[, 1] <- NULL 
qvalues <- qvalue(p_values)$qvalue
write.csv(qvalues, file = output_file_qvalue)
# Out:
# Error in p_values[, 1] <- NULL: number of items to replace is not a multiple of replacement length
# Traceback:

# %%
p_values <- pv$pvalues

# %%
qvalues <- qvalue(p_values)$qvalue
# Out:
# Error in qvalue(p_values): could not find function "qvalue"
# Traceback:

# %%
p_values
# Out:
#      Response Y1 Response Y2 Response Y3 Response Y4 Response Y5 Response Y6
# X1   0.12344515  0.12068234  0.098530047 0.1660560   0.58789929  0.6957139
# X2   0.60475047  0.54815149  0.652636624 0.1644004   0.93622955  0.8265308
# X3   0.77704358  0.54972129  0.761487599 0.1867598   0.90661342  0.8165171
# X4   0.81551370  0.55235320  0.187613618 0.4982334   0.66966792  0.9156725
# X5   0.22559346  0.80729547  0.506575618 0.1975499   0.88345879  0.7670978
# X6   0.69176903  0.50850186  0.676352281 0.1539874   0.95821934  0.7464694
# X8   0.46890020  0.07862963  0.227062347 0.2688790   0.70537390  0.2469908
# X9   0.09202288  0.77602583  0.021930122 0.8059264   0.07203301  0.7031027
# X10  0.12832099  0.50467164  0.904986370 0.1042759   0.40024306  0.8073969
# X11  0.76756281  0.23033694  0.140312860 0.7109623   0.76752927  0.9155470
# X12  0.37488155  0.80942516  0.008923416 0.4432241   0.31659431  0.6822369
# X13  0.08807853  0.27186897  0.274132417 0.1322202   0.20933337  0.1974846
# X14  0.52416783  0.85849357  0.205312385 0.4836427   0.89338060  0.8324994
# X15  0.06352684  0.07617425  0.773323511 0.6353404   0.16752166  0.2749018
# X16  0.23122155  0.83886076  0.004881522 0.8079334   0.21682904  0.3921390
# X17  0.25194775  0.67683063  0.474414951 0.3048068   0.27428947  0.6588713
# X18  0.43520968  0.09082893  0.005674970 0.4589072   0.55563628  0.5094662
# X19  0.58786216  0.82740765  0.152243913 0.6544268   0.37055594  0.2340418
# X1.1 0.88417815  0.35315163  0.896117329 0.4807296   0.48614672  0.9105270
#      Response Y7 Response Y8 Response Y9 Response Y10 ⋯ Response Y13976
# X1   0.2787549   0.10712266  0.6703916   0.60465902   ⋯ 0.38344122
# X2   0.2691981   0.34990520  0.4529198   0.04489110   ⋯ 0.64755334
# X3   0.2303761   0.34228285  0.4410717   0.07137639   ⋯ 0.48070957
# X4   0.2520055   0.73025281  0.2722027   0.45503656   ⋯ 0.22020445
# X5   0.4148335   0.42817613  0.4986969   0.01967082   ⋯ 0.94358137
# X6   0.2278709   0.31448216  0.4943770   0.04399881   ⋯ 0.64897496
# X8   0.4097913   0.23269795  0.7835906   0.09519039   ⋯ 0.10817545
# X9   0.9600825   0.89192005  0.7184467   0.66191288   ⋯ 0.03978827
# X10  0.8725984   0.42779385  0.5655437   0.51513949   ⋯ 0.97375841
# X11  0.1468957   0.24231979  0.3600553   0.37398965   ⋯ 0.13050425
# X12  0.4511570   0.94754499  0.7928703   0.79133117   ⋯ 0.19743063
# X13  0.5748546   0.08750886  0.4959135   0.98762002   ⋯ 0.50443878
# X14  0.6766494   0.60496764  0.5009383   0.50422047   ⋯ 0.88645981
# X15  0.9993565   0.85797431  0.7558694   0.34689770   ⋯ 0.31473330
# X16  0.4513801   0.55639586  0.9724588   0.68327480   ⋯ 0.45258808
# X17  0.3689663   0.39932845  0.4684499   0.49549089   ⋯ 0.04627409
# X18  0.3593240   0.13943906  0.6819095   0.79560856   ⋯ 0.24774752
# X19  0.1699037   0.72340539  0.5472288   0.10178284   ⋯ 0.48726692
# X1.1 0.8634649   0.79811974  0.1460087   0.60725785   ⋯ 0.40808348
#      Response Y13977 Response Y13978 Response Y13979 Response Y13980
# X1   0.7268407       0.338272462     0.5065847       0.8738041
# X2   0.3621057       0.442988331     0.3615960       0.9807551
# X3   0.3637447       0.415845199     0.3871659       0.9427586
# X4   0.4483174       0.007915536     0.1437180       0.5242354
# X5   0.3710644       0.533408489     0.3760530       0.9250077
# X6   0.3144929       0.511719382     0.4074659       0.9800190
# X8   0.9316348       0.107359795     0.8019740       0.5430881
# X9   0.6627018       0.532716364     0.1947782       0.4813661
# X10  0.6951347       0.133650268     0.3691740       0.5492565
# X11  0.3406614       0.020214200     0.2768568       0.7952085
# X12  0.4893126       0.453126296     0.8279817       0.9513548
# X13  0.9620030       0.734588234     0.6795689       0.3058188
# X14  0.9969917       0.649296777     0.8392962       0.2162156
# X15  0.4489250       0.744939463     0.3670404       0.3183154
# X16  0.5686910       0.421400881     0.6741810       0.6717370
# X17  0.2948160       0.142488200     0.9010832       0.4455198
# X18  0.5751354       0.110898361     0.5084511       0.6898441
# X19  0.5343752       0.269863967     0.2282040       0.3899828
# X1.1 0.9475229       0.056888723     0.9294002       0.8646064
#      Response Y13981 Response Y13982 Response Y13983 Response Y13984
# X1   0.56501013      0.1936484       0.9996424       0.10413663
# X2   0.06097552      0.6297233       0.7427395       0.10327007
# X3   0.05832713      0.7646786       0.7359990       0.09527294
# X4   0.01240564      0.7027455       0.4051547       0.06709943
# X5   0.09278688      0.4421258       0.8077837       0.16450401
# X6   0.07568845      0.6996802       0.7699297       0.10834027
# X8   0.59637202      0.7316431       0.4114908       0.96259701
# X9   0.98126212      0.9282036       0.8816298       0.39338536
# X10  0.10213341      0.2171471       0.5590763       0.64231724
# X11  0.04490921      0.8021521       0.5674310       0.04296791
# X12  0.21391193      0.5973817       0.8467344       0.95495416
# X13  0.64817094      0.9343592       0.6015245       0.33866009
# X14  0.81595330      0.9918053       0.6856322       0.26289147
# X15  0.63793518      0.6178558       0.5214620       0.94694192
# X16  0.08497221      0.7287908       0.9738673       0.94383663
# X17  0.17169437      0.8172999       0.9997028       0.29333431
# X18  0.48334091      0.7605758       0.5625554       0.17596091
# X19  0.01707478      0.6212506       0.9055029       0.37745365
# X1.1 0.53698145      0.8299052       0.4863937       0.73705642
#      Response Y13985
# X1   0.50348533
# X2   0.92286874
# X3   0.87590825
# X4   0.52069983
# X5   0.95944042
# X6   0.89182195
# X8   0.49669512
# X9   0.17785957
# X10  0.33109188
# X11  0.73106738
# X12  0.17541452
# X13  0.68697153
# X14  0.08862101
# X15  0.80973045
# X16  0.35455534
# X17  0.60843396
# X18  0.47922922
# X19  0.86096964
# X1.1 0.33496419

# %%
library("LEA")
library("dplyr")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
path_ldp_af = '/carnegie/nobackup/scratch/xwu/grenet/merged_frequency/merged_hapFIRE_allele_frequency_LDpruned.txt'
results_dir = sprintf('/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_%d', split_number)

k <- as.integer(readLines(sprintf('%s/num_components.txt', results_dir)))
env <- read.csv(sprintf('%s/environment_lea.csv', results_dir), header = TRUE, colClasses = "numeric")
rownames(env) <- NULL
colnames(env) <- NULL
env <- as.matrix(env)


file_name <- basename(path_ldp_af)
output_file_pvalue <- paste0(results_dir, "/pvalues.csv")
output_file_zscores <- paste0(results_dir, "/zscores.csv")
output_file_gif <- paste0(results_dir, "/gif.csv")

# %%
output_file_pvalue
# Out:
# [1] "/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_0/pvalues.csv"

# %%
allele_freq <- read.table(path_ldp_af, sep = '\t', header = TRUE, check.names = FALSE)
allele_freq <- allele_freq[, train_samples_vector]  # Use dynamic columns
colnames(allele_freq) <- NULL
allele_freq <- t(as.matrix(allele_freq))

mod2 <- lfmm2(input = allele_freq, env = env, K = k)
pv <- lfmm2.test(object = mod2, input = allele_freq, env = env, calibrate = "gif")

p_values <- pv$pvalues
zscores <- pv$zscores
gif <- pv$gif
# Out:
# Error in lfmm2.test(object = mod2, input = allele_freq, env = env, calibrate = "gif"): unused argument (calibrate = "gif")
# Traceback:

# %%
pv

# %%
if (!require("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("qvalue")
# Out:
# Bioconductor version '3.16' is out-of-date; the current release version '3.19'
#   is available with R version '4.4'; see https://bioconductor.org/install
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.16 (BiocManager 1.30.22), R 4.2.3 (2023-03-15)
#
# Installing package(s) 'qvalue'
#
# also installing the dependencies ‘colorspace’, ‘farver’, ‘munsell’, ‘isoband’, ‘scales’, ‘plyr’, ‘ggplot2’, ‘reshape2’
#
#
# Warning message in install.packages(...):
# “installation of package ‘colorspace’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘farver’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘isoband’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘plyr’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘munsell’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘reshape2’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘scales’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘ggplot2’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘qvalue’ had non-zero exit status”
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Old packages: 'ape', 'BiocManager', 'brio', 'fastmap', 'fs', 'gert', 'httpuv',
#   'LEA', 'openssl', 'ragg', 'stringi', 'survival', 'systemfonts', 'tinytex',
#   'vegan', 'xfun'

# %%
library("qvalue")   # Used to post-process LFMM output
# Out:
# Error in library("qvalue"): there is no package called ‘qvalue’
# Traceback:
#
# 1. library("qvalue")

# %%
wolf.qv <- qvalue(p_values)
# Out:
# Error in qvalue(p_values): could not find function "qvalue"
# Traceback:

# %%
wolf.qv

# %%
length(which(wolf.qv < 0.1)) ## h.w many SNPs have an FDR < 10%?

# %%
write.csv(p_values, file = output_file_pvalue)
write.csv(zscores, file = output_file_zscores)
write.csv(gif, file = output_file_gif)

# %%
library("LEA")
library("dplyr")
library("qvalue")

# %%
output_file_pvalue = '/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_0/pvalues.csv'

output_file_zscores = '/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_0/zscores.csv'

output_file_gif = '/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_0/gif.csv'

pvalues = read.table(output_file_pvalue, sep = ',', header = TRUE, check.names = FALSE)
pvalues[, 1] <- NULL 
qvalues <- qvalue(pvalues)$qvalue

output_file_qvalue = '/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_0/qvalues.csv'
write.csv(qvalues, file = output_file_qvalue)

# %%
results_dir
# Out:
# [1] "/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_0"

# %%
dir_compl = '/carnegie/nobackup/scratch/tbellagio/gea_grene-net/leave_1_out/split_number_99/environment_lea.csv'

# %%
env <- read.csv(dir_compl, header = TRUE, colClasses = "numeric")

# %%
head(env)
# Out:
#   bio1       bio2      bio3      bio4       bio5      bio6      bio7
# 1 -0.6190614 0.2122731 -0.406939 -0.2283215 -0.255796 -0.534303 0.4333158
# 2 -0.6190614 0.2122731 -0.406939 -0.2283215 -0.255796 -0.534303 0.4333158
# 3 -0.6190614 0.2122731 -0.406939 -0.2283215 -0.255796 -0.534303 0.4333158
# 4 -0.6190614 0.2122731 -0.406939 -0.2283215 -0.255796 -0.534303 0.4333158
# 5 -0.6190614 0.2122731 -0.406939 -0.2283215 -0.255796 -0.534303 0.4333158
# 6 -0.6190614 0.2122731 -0.406939 -0.2283215 -0.255796 -0.534303 0.4333158
#   bio8      bio9       bio10      bio11      bio12      bio13      bio14
# 1 -1.779003 -0.3269142 -0.7939223 -0.3952245 -0.2172948 -0.3933985 -0.08337791
# 2 -1.779003 -0.3269142 -0.7939223 -0.3952245 -0.2172948 -0.3933985 -0.08337791
# 3 -1.779003 -0.3269142 -0.7939223 -0.3952245 -0.2172948 -0.3933985 -0.08337791
# 4 -1.779003 -0.3269142 -0.7939223 -0.3952245 -0.2172948 -0.3933985 -0.08337791
# 5 -1.779003 -0.3269142 -0.7939223 -0.3952245 -0.2172948 -0.3933985 -0.08337791
# 6 -1.779003 -0.3269142 -0.7939223 -0.3952245 -0.2172948 -0.3933985 -0.08337791
#   bio15      bio16      bio17       bio18       bio19
# 1 -0.4393859 -0.2540141 -0.06189188 -0.03557643 0.1992312
# 2 -0.4393859 -0.2540141 -0.06189188 -0.03557643 0.1992312
# 3 -0.4393859 -0.2540141 -0.06189188 -0.03557643 0.1992312
# 4 -0.4393859 -0.2540141 -0.06189188 -0.03557643 0.1992312
# 5 -0.4393859 -0.2540141 -0.06189188 -0.03557643 0.1992312
# 6 -0.4393859 -0.2540141 -0.06189188 -0.03557643 0.1992312

# %%
rownames(env) <- NULL
colnames(env) <- NULL

# %%
head(env)
# Out:
#   [,1]       [,2]      [,3]      [,4]       [,5]      [,6]      [,7]
# 1 -0.6190614 0.2122731 -0.406939 -0.2283215 -0.255796 -0.534303 0.4333158
# 2 -0.6190614 0.2122731 -0.406939 -0.2283215 -0.255796 -0.534303 0.4333158
# 3 -0.6190614 0.2122731 -0.406939 -0.2283215 -0.255796 -0.534303 0.4333158
# 4 -0.6190614 0.2122731 -0.406939 -0.2283215 -0.255796 -0.534303 0.4333158
# 5 -0.6190614 0.2122731 -0.406939 -0.2283215 -0.255796 -0.534303 0.4333158
# 6 -0.6190614 0.2122731 -0.406939 -0.2283215 -0.255796 -0.534303 0.4333158
#   [,8]      [,9]       [,10]      [,11]      [,12]      [,13]      [,14]
# 1 -1.779003 -0.3269142 -0.7939223 -0.3952245 -0.2172948 -0.3933985 -0.08337791
# 2 -1.779003 -0.3269142 -0.7939223 -0.3952245 -0.2172948 -0.3933985 -0.08337791
# 3 -1.779003 -0.3269142 -0.7939223 -0.3952245 -0.2172948 -0.3933985 -0.08337791
# 4 -1.779003 -0.3269142 -0.7939223 -0.3952245 -0.2172948 -0.3933985 -0.08337791
# 5 -1.779003 -0.3269142 -0.7939223 -0.3952245 -0.2172948 -0.3933985 -0.08337791
# 6 -1.779003 -0.3269142 -0.7939223 -0.3952245 -0.2172948 -0.3933985 -0.08337791
#   [,15]      [,16]      [,17]       [,18]       [,19]
# 1 -0.4393859 -0.2540141 -0.06189188 -0.03557643 0.1992312
# 2 -0.4393859 -0.2540141 -0.06189188 -0.03557643 0.1992312
# 3 -0.4393859 -0.2540141 -0.06189188 -0.03557643 0.1992312
# 4 -0.4393859 -0.2540141 -0.06189188 -0.03557643 0.1992312
# 5 -0.4393859 -0.2540141 -0.06189188 -0.03557643 0.1992312
# 6 -0.4393859 -0.2540141 -0.06189188 -0.03557643 0.1992312

# %%
env <- as.matrix(env)

# %%
env[, 1]
# Out:
#   [1] -0.6190614 -0.6190614 -0.6190614 -0.6190614 -0.6190614 -0.6190614
#   [7] -0.6190614 -0.6190614 -0.6190614 -0.6190614 -0.6190614 -0.6190614
#  [13]  0.9147688  0.9147688  0.9147688  0.9147688  0.9147688  0.9147688
#  [19]  0.9147688  0.9147688  0.9147688  0.9147688  0.9147688  0.9147688
#  [25] -0.2253239 -0.2253239 -0.2253239 -0.2253239 -0.2253239 -0.2253239
#  [31] -0.2253239 -0.2253239 -0.2253239 -0.2253239 -0.2253239 -0.2253239
#  [37]  1.6029856  1.6029856  1.6029856  1.6029856  1.6029856  1.6029856
#  [43]  1.6029856  1.6029856  1.6029856  1.6029856  1.6029856  1.6029856
#  [49] -0.1175879 -0.1175879 -0.1175879 -0.1175879 -0.1175879 -0.1175879
#  [55] -0.1175879 -0.1175879 -0.1175879 -0.1175879 -0.1175879  1.5716697
#  [61]  1.5716697  1.5716697  1.5716697  1.5716697  1.5716697  1.5716697
#  [67]  1.5716697  1.5716697  1.5716697  1.5716697  1.5716697 -1.4014391
