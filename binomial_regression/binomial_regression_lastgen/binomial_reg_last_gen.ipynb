# %%
import pandas as pd
import pickle

import statsmodels.api as sm
from statsmodels.formula.api import glm

from sklearn.preprocessing import StandardScaler


import seaborn as sns
import numpy as np
import matplotlib.pyplot as pl
import os

# %%
biovar = 'bio18'

# %%
#finalgen_samples = pd.read_csv('../final_gen.csv')['sample_name']
last_gen = pd.read_csv('../key_files/final_gen.csv')['sample_name']
## eliminate site 33 
last_gen = last_gen[~last_gen.str.startswith('33_')]
## eliminate site 33 
samples = last_gen.to_list()

# %%
clim_sites_during_exp = pd.read_csv('/carnegie/nobackup/scratch/tbellagio/grene/data/bioclimvars_experimental_sites_era5.csv')
#clim_sites_during_exp = pd.read_csv('../key_files/bioclimvars_sites_era5_year_2018.csv')

sites_af = pd.Series(samples).str.split('_').str[0].astype(int)

sites_af.name = 'site'

# %%
env = sites_af.reset_index().merge(clim_sites_during_exp).drop(['index'],axis=1)

# %%
biovars = ['bio1', 'bio2', 'bio3', 'bio4', 'bio5', 'bio6', 'bio7', 'bio8',
       'bio9', 'bio10', 'bio11', 'bio12', 'bio13', 'bio14', 'bio15', 'bio16',
       'bio17', 'bio18', 'bio19']

# %%
for biovar in biovars:

    env_variable = env[biovar]
    
    # Standardize the environmental variable
    scaler = StandardScaler()
    env_variable_scaled = scaler.fit_transform(env_variable.values.reshape(-1, 1))
    
    pd.DataFrame(env_variable_scaled).to_csv(f'env_{biovar}.csv',index=None)

# %%
files = os.listdir('../baypass_lastgen/individual_gfiles_last_gen/')

# %%
partitions = [int(file.split('_')[1].replace('.txt', '')) for file in files if '.txt' in file]

# %%
partitions.sort()

# %%
pwd -P
# Out:
# '/carnegie/nobackup/scratch/tbellagio/gea_grene-net/binomial_regression_lastgen'

# %%
import random
import subprocess

# %%
biovar
# Out:
# 'bio18'

# %%
biovars = [
 'bio2',
 'bio3',
 'bio4',
 'bio5',
 'bio6',
 'bio7',
 'bio8',
 'bio9',
 'bio10',
 'bio11',
 'bio13',
 'bio14',
 'bio15',
 'bio16',
 'bio17',
 'bio19']

# %%
# create sbatch files to submit on server
shfiles = []
for biovar in biovars:
    for partition in partitions:
        seed = random.randint(1,100000000)
        file = f'shfiles/partition_{partition}_{biovar}.sh'
        cmd = f'python run_partition_binomial_reg_last_gen.py {partition} {biovar}'
        text = f'''#!/bin/bash
#SBATCH --job-name=run_partition_binomial_reg{partition}
#SBATCH --time=4:00:00  # Time limit set to 4 days
#SBATCH --ntasks=1
#SBATCH --mem-per-cpu=30gb
#SBATCH --output=run_partition_binomial_reg{partition}_{biovar}_%j.out
#SBATCH --mail-user=tbellagio@carnegiescience.edu
#SBATCH --mail-type=FAIL

module load python/3.11_conda
conda activate /home/tbellagio/miniforge3/envs/pipeline_snakemake
export LD_LIBRARY_PATH="/home/tbellagio/miniforge3/envs/run_baypass/lib:$LD_LIBRARY_PATH"
cd /carnegie/nobackup/scratch/tbellagio/gea_grene-net/binomial_regression_lastgen
{cmd}

'''
        with open(file, 'w') as o:
            o.write("%s" % text)
        shfiles.append(file)
        #print(file)

# %%
len(shfiles)
# Out:
# 3150

# %%
#subprocess.run(["sbatch", shfiles[0]], check=True)

# %%
import subprocess
import time

# Process files in batches of 100
for i in range(0, len(shfiles), 100):
    # Get the next batch of up to 100 files
    batch = shfiles[i:i+100]

    # Submit each sbatch script in the current batch to the SLURM scheduler
    for shfile in batch:
        subprocess.run(["sbatch", shfile], check=True)

    # Wait for 2 minutes (120 seconds) before submitting the next batch
    if i + 100 < len(shfiles):  # Prevent waiting after the last batch
        time.sleep(120)
# Out:
# Submitted batch job 58608
# Submitted batch job 58609
# Submitted batch job 58610
# Submitted batch job 58611
# Submitted batch job 58612
# Submitted batch job 58613
# Submitted batch job 58614
# Submitted batch job 58615
# Submitted batch job 58616
# Submitted batch job 58617
# Submitted batch job 58618
# Submitted batch job 58619
# Submitted batch job 58620
# Submitted batch job 58621
# Submitted batch job 58622
# Submitted batch job 58623
# Submitted batch job 58624
# Submitted batch job 58625
# Submitted batch job 58626
# Submitted batch job 58627
# Submitted batch job 58628
# Submitted batch job 58629
# Submitted batch job 58630
# Submitted batch job 58631
# Submitted batch job 58632
# Submitted batch job 58633
# Submitted batch job 58634
# Submitted batch job 58635
# Submitted batch job 58636
# Submitted batch job 58637
# Submitted batch job 58638
# Submitted batch job 58639
# Submitted batch job 58640
# Submitted batch job 58641
# Submitted batch job 58642
# Submitted batch job 58643
# Submitted batch job 58644
# Submitted batch job 58645
# Submitted batch job 58646
# Submitted batch job 58647
# Submitted batch job 58648
# Submitted batch job 58649
# Submitted batch job 58650
# Submitted batch job 58651
# Submitted batch job 58652
# Submitted batch job 58653
# Submitted batch job 58654
# Submitted batch job 58655
# Submitted batch job 58656
# Submitted batch job 58657
# Submitted batch job 58658
# Submitted batch job 58659
# Submitted batch job 58660
# Submitted batch job 58661
# Submitted batch job 58662
# Submitted batch job 58663
# Submitted batch job 58664
# Submitted batch job 58665
# Submitted batch job 58666
# Submitted batch job 58667
# Submitted batch job 58668
# Submitted batch job 58669
# Submitted batch job 58670
# Submitted batch job 58671
# Submitted batch job 58672
# Submitted batch job 58673
# Submitted batch job 58674
# Submitted batch job 58675
# Submitted batch job 58676
# Submitted batch job 58677
# Submitted batch job 58678
# Submitted batch job 58679
# Submitted batch job 58680
# Submitted batch job 58681
# Submitted batch job 58682
# Submitted batch job 58683
# Submitted batch job 58684
# Submitted batch job 58685
# Submitted batch job 58686
# Submitted batch job 58687
# Submitted batch job 58688
# Submitted batch job 58689
# Submitted batch job 58690
# Submitted batch job 58691
# Submitted batch job 58692
# Submitted batch job 58693
# Submitted batch job 58694
# Submitted batch job 58695
# Submitted batch job 58696
# Submitted batch job 58697
# Submitted batch job 58698
# Submitted batch job 58699
# Submitted batch job 58700
# Submitted batch job 58701
# Submitted batch job 58702
# Submitted batch job 58703
# Submitted batch job 58704
# Submitted batch job 58705
# Submitted batch job 58706
# Submitted batch job 58707
# Submitted batch job 58708
# Submitted batch job 58709
# Submitted batch job 58710
# Submitted batch job 58711
# Submitted batch job 58712
# Submitted batch job 58713
# Submitted batch job 58714
# Submitted batch job 58715
# Submitted batch job 58716
# Submitted batch job 58717
# Submitted batch job 58718
# Submitted batch job 58719
# Submitted batch job 58720
# Submitted batch job 58721
# Submitted batch job 58722
# Submitted batch job 58723
# Submitted batch job 58724
# Submitted batch job 58725
# Submitted batch job 58726
# Submitted batch job 58727
# Submitted batch job 58728
# Submitted batch job 58729
# Submitted batch job 58730
# Submitted batch job 58731
# Submitted batch job 58732
# Submitted batch job 58733
# Submitted batch job 58734
# Submitted batch job 58735
# Submitted batch job 58736
# Submitted batch job 58737
# Submitted batch job 58738
# Submitted batch job 58739
# Submitted batch job 58740
# Submitted batch job 58741
# Submitted batch job 58742
# Submitted batch job 58743
# Submitted batch job 58744
# Submitted batch job 58745
# Submitted batch job 58746
# Submitted batch job 58747
# Submitted batch job 58748
# Submitted batch job 58749
# Submitted batch job 58750
# Submitted batch job 58751
# Submitted batch job 58752
# Submitted batch job 58753
# Submitted batch job 58754
# Submitted batch job 58755
# Submitted batch job 58756
# Submitted batch job 58757
# Submitted batch job 58758
# Submitted batch job 58759
# Submitted batch job 58760
# Submitted batch job 58761
# Submitted batch job 58762
# Submitted batch job 58763
# Submitted batch job 58764
# Submitted batch job 58765
# Submitted batch job 58766
# Submitted batch job 58767
# Submitted batch job 58768
# Submitted batch job 58769
# Submitted batch job 58770
# Submitted batch job 58771
# Submitted batch job 58772
# Submitted batch job 58773
# Submitted batch job 58774
# Submitted batch job 58775
# Submitted batch job 58776
# Submitted batch job 58777
# Submitted batch job 58778
# Submitted batch job 58779
# Submitted batch job 58780
# Submitted batch job 58781
# Submitted batch job 58782
# Submitted batch job 58783
# Submitted batch job 58784
# Submitted batch job 58785
# Submitted batch job 58786
# Submitted batch job 58787
# Submitted batch job 58788
# Submitted batch job 58789
# Submitted batch job 58790
# Submitted batch job 58791
# Submitted batch job 58792
# Submitted batch job 58793
# Submitted batch job 58794
# Submitted batch job 58795
# Submitted batch job 58796
# Submitted batch job 58797
# Submitted batch job 58798
# Submitted batch job 58799
# Submitted batch job 58800
# Submitted batch job 58801
# Submitted batch job 58802
# Submitted batch job 58803
# Submitted batch job 58804
# Submitted batch job 58805
# Submitted batch job 58806
# Submitted batch job 58807
# Submitted batch job 58808
# Submitted batch job 58809
# Submitted batch job 58810
# Submitted batch job 58811
# Submitted batch job 58812
# Submitted batch job 58813
# Submitted batch job 58814
# Submitted batch job 58815
# Submitted batch job 58816
# Submitted batch job 58817
# Submitted batch job 58818
# Submitted batch job 58819
# Submitted batch job 58820
# Submitted batch job 58821
# Submitted batch job 58822
# Submitted batch job 58823
# Submitted batch job 58824
# Submitted batch job 58825
# Submitted batch job 58826
# Submitted batch job 58827
# Submitted batch job 58828
# Submitted batch job 58829
# Submitted batch job 58830
# Submitted batch job 58831
# Submitted batch job 58832
# Submitted batch job 58833
# Submitted batch job 58834
# Submitted batch job 58835
# Submitted batch job 58836
# Submitted batch job 58837
# Submitted batch job 58838
# Submitted batch job 58839
# Submitted batch job 58840
# Submitted batch job 58841
# Submitted batch job 58842
# Submitted batch job 58843
# Submitted batch job 58844
# Submitted batch job 58845
# Submitted batch job 58846
# Submitted batch job 58847
# Submitted batch job 58848
# Submitted batch job 58849
# Submitted batch job 58850
# Submitted batch job 58851
# Submitted batch job 58852
# Submitted batch job 58853
# Submitted batch job 58854
# Submitted batch job 58855
# Submitted batch job 58856
# Submitted batch job 58857
# Submitted batch job 58858
# Submitted batch job 58859
# Submitted batch job 58860
# Submitted batch job 58861
# Submitted batch job 58862
# Submitted batch job 58863
# Submitted batch job 58864
# Submitted batch job 58865
# Submitted batch job 58866
# Submitted batch job 58867
# Submitted batch job 58868
# Submitted batch job 58869
# Submitted batch job 58870
# Submitted batch job 58871
# Submitted batch job 58872
# Submitted batch job 58873
# Submitted batch job 58874
# Submitted batch job 58875
# Submitted batch job 58876
# Submitted batch job 58877
# Submitted batch job 58878
# Submitted batch job 58879
# Submitted batch job 58880
# Submitted batch job 58881
# Submitted batch job 58882
# Submitted batch job 58883
# Submitted batch job 58884
# Submitted batch job 58885
# Submitted batch job 58886
# Submitted batch job 58887
# Submitted batch job 58888
# Submitted batch job 58889
# Submitted batch job 58890
# Submitted batch job 58891
# Submitted batch job 58892
# Submitted batch job 58893
# Submitted batch job 58894
# Submitted batch job 58895
# Submitted batch job 58896
# Submitted batch job 58897
# Submitted batch job 58898
# Submitted batch job 58899
# Submitted batch job 58900
# Submitted batch job 58901
# Submitted batch job 58902
# Submitted batch job 58903
# Submitted batch job 58904
# Submitted batch job 58905
# Submitted batch job 58906
# Submitted batch job 58907
# Submitted batch job 58908
# Submitted batch job 58909
# Submitted batch job 58910
# Submitted batch job 58911
# Submitted batch job 58912
# Submitted batch job 58913
# Submitted batch job 58914
# Submitted batch job 58915
# Submitted batch job 58916
# Submitted batch job 58917
# Submitted batch job 58918
# Submitted batch job 58919
# Submitted batch job 58920
# Submitted batch job 58921
# Submitted batch job 58922
# Submitted batch job 58923
# Submitted batch job 58924
# Submitted batch job 58925
# Submitted batch job 58926
# Submitted batch job 58927
# Submitted batch job 58928
# Submitted batch job 58929
# Submitted batch job 58930
# Submitted batch job 58931
# Submitted batch job 58932
# Submitted batch job 58933
# Submitted batch job 58934
# Submitted batch job 58935
# Submitted batch job 58936
# Submitted batch job 58937
# Submitted batch job 58938
# Submitted batch job 58939
# Submitted batch job 58940
# Submitted batch job 58941
# Submitted batch job 58942
# Submitted batch job 58943
# Submitted batch job 58944
# Submitted batch job 58945
# Submitted batch job 58946
# Submitted batch job 58947
# Submitted batch job 58948
# Submitted batch job 58949
# Submitted batch job 58950
# Submitted batch job 58951
# Submitted batch job 58952
# Submitted batch job 58953
# Submitted batch job 58954
# Submitted batch job 58955
# Submitted batch job 58956
# Submitted batch job 58957
# Submitted batch job 58958
# Submitted batch job 58959
# Submitted batch job 58960
# Submitted batch job 58961
# Submitted batch job 58962
# Submitted batch job 58963
# Submitted batch job 58964
# Submitted batch job 58965
# Submitted batch job 58966
# Submitted batch job 58967
# Submitted batch job 58968
# Submitted batch job 58969
# Submitted batch job 58970
# Submitted batch job 58971
# Submitted batch job 58972
# Submitted batch job 58973
# Submitted batch job 58974
# Submitted batch job 58975
# Submitted batch job 58976
# Submitted batch job 58977
# Submitted batch job 58978
# Submitted batch job 58979
# Submitted batch job 58980
# Submitted batch job 58981
# Submitted batch job 58982
# Submitted batch job 58983
# Submitted batch job 58984
# Submitted batch job 58985
# Submitted batch job 58986
# Submitted batch job 58987
# Submitted batch job 58988
# Submitted batch job 58989
# Submitted batch job 58990
# Submitted batch job 58991
# Submitted batch job 58992
# Submitted batch job 58993
# Submitted batch job 58994
# Submitted batch job 58995
# Submitted batch job 58996
# Submitted batch job 58997
# Submitted batch job 58998
# Submitted batch job 58999
# Submitted batch job 59000
# Submitted batch job 59001
# Submitted batch job 59002
# Submitted batch job 59003
# Submitted batch job 59004
# Submitted batch job 59005
# Submitted batch job 59006
# Submitted batch job 59007
# Submitted batch job 59008
# Submitted batch job 59009
# Submitted batch job 59010
# Submitted batch job 59011
# Submitted batch job 59012
# Submitted batch job 59013
# Submitted batch job 59014
# Submitted batch job 59015
# Submitted batch job 59016
# Submitted batch job 59017
# Submitted batch job 59018
# Submitted batch job 59019
# Submitted batch job 59020
# Submitted batch job 59021
# Submitted batch job 59022
# Submitted batch job 59023
# Submitted batch job 59024
# Submitted batch job 59025
# Submitted batch job 59026
# Submitted batch job 59027
# Submitted batch job 59028
# Submitted batch job 59029
# Submitted batch job 59030
# Submitted batch job 59031
# Submitted batch job 59032
# Submitted batch job 59033
# Submitted batch job 59034
# Submitted batch job 59035
# Submitted batch job 59036
# Submitted batch job 59037
# Submitted batch job 59038
# Submitted batch job 59039
# Submitted batch job 59040
# Submitted batch job 59041
# Submitted batch job 59042
# Submitted batch job 59043
# Submitted batch job 59044
# Submitted batch job 59045
# Submitted batch job 59046
# Submitted batch job 59047
# Submitted batch job 59048
# Submitted batch job 59049
# Submitted batch job 59050
# Submitted batch job 59051
# Submitted batch job 59052
# Submitted batch job 59053
# Submitted batch job 59054
# Submitted batch job 59055
# Submitted batch job 59056
# Submitted batch job 59057
# Submitted batch job 59058
# Submitted batch job 59059
# Submitted batch job 59060
# Submitted batch job 59061
# Submitted batch job 59062
# Submitted batch job 59063
# Submitted batch job 59064
# Submitted batch job 59065
# Submitted batch job 59066
# Submitted batch job 59067
# Submitted batch job 59068
# Submitted batch job 59069
# Submitted batch job 59070
# Submitted batch job 59071
# Submitted batch job 59072
# Submitted batch job 59073
# Submitted batch job 59074
# Submitted batch job 59075
# Submitted batch job 59076
# Submitted batch job 59077
# Submitted batch job 59078
# Submitted batch job 59079
# Submitted batch job 59080
# Submitted batch job 59081
# Submitted batch job 59082
# Submitted batch job 59083
# Submitted batch job 59084
# Submitted batch job 59085
# Submitted batch job 59086
# Submitted batch job 59087
# Submitted batch job 59088
# Submitted batch job 59089
# Submitted batch job 59090
# Submitted batch job 59091
# Submitted batch job 59092
# Submitted batch job 59093
# Submitted batch job 59094
# Submitted batch job 59095
# Submitted batch job 59096
# Submitted batch job 59097
# Submitted batch job 59098
# Submitted batch job 59099
# Submitted batch job 59100
# Submitted batch job 59101
# Submitted batch job 59102
# Submitted batch job 59103
# Submitted batch job 59104
# Submitted batch job 59105
# Submitted batch job 59106
# Submitted batch job 59107
# Submitted batch job 59108
# Submitted batch job 59109
# Submitted batch job 59110
# Submitted batch job 59111
# Submitted batch job 59112
# Submitted batch job 59113
# Submitted batch job 59114
# Submitted batch job 59115
# Submitted batch job 59116
# Submitted batch job 59117
# Submitted batch job 59118
# Submitted batch job 59119
# Submitted batch job 59120
# Submitted batch job 59121
# Submitted batch job 59122
# Submitted batch job 59123
# Submitted batch job 59124
# Submitted batch job 59125
# Submitted batch job 59126
# Submitted batch job 59127
# Submitted batch job 59128
# Submitted batch job 59129
# Submitted batch job 59130
# Submitted batch job 59131
# Submitted batch job 59132
# Submitted batch job 59133
# Submitted batch job 59134
# Submitted batch job 59135
# Submitted batch job 59136
# Submitted batch job 59137
# Submitted batch job 59138
# Submitted batch job 59139
# Submitted batch job 59140
# Submitted batch job 59141
# Submitted batch job 59142
# Submitted batch job 59143
# Submitted batch job 59144
# Submitted batch job 59145
# Submitted batch job 59146
# Submitted batch job 59147
# Submitted batch job 59148
# Submitted batch job 59149
# Submitted batch job 59150
# Submitted batch job 59151
# Submitted batch job 59152
# Submitted batch job 59153
# Submitted batch job 59154
# Submitted batch job 59155
# Submitted batch job 59156
# Submitted batch job 59157
# Submitted batch job 59158
# Submitted batch job 59159
# Submitted batch job 59160
# Submitted batch job 59161
# Submitted batch job 59162
# Submitted batch job 59163
# Submitted batch job 59164
# Submitted batch job 59165
# Submitted batch job 59166
# Submitted batch job 59167
# Submitted batch job 59168
# Submitted batch job 59169
# Submitted batch job 59170
# Submitted batch job 59171
# Submitted batch job 59172
# Submitted batch job 59173
# Submitted batch job 59174
# Submitted batch job 59175
# Submitted batch job 59176
# Submitted batch job 59177
# Submitted batch job 59178
# Submitted batch job 59179
# Submitted batch job 59180
# Submitted batch job 59181
# Submitted batch job 59182
# Submitted batch job 59183
# Submitted batch job 59184
# Submitted batch job 59185
# Submitted batch job 59186
# Submitted batch job 59187
# Submitted batch job 59188
# Submitted batch job 59189
# Submitted batch job 59190
# Submitted batch job 59191
# Submitted batch job 59192
# Submitted batch job 59193
# Submitted batch job 59194
# Submitted batch job 59195
# Submitted batch job 59196
# Submitted batch job 59197
# Submitted batch job 59198
# Submitted batch job 59199
# Submitted batch job 59200
# Submitted batch job 59201
# Submitted batch job 59202
# Submitted batch job 59203
# Submitted batch job 59204
# Submitted batch job 59205
# Submitted batch job 59206
# Submitted batch job 59207
# Submitted batch job 59208
# Submitted batch job 59209
# Submitted batch job 59210
# Submitted batch job 59211
# Submitted batch job 59212
# Submitted batch job 59213
# Submitted batch job 59214
# Submitted batch job 59215
# Submitted batch job 59216
# Submitted batch job 59217
# Submitted batch job 59218
# Submitted batch job 59219
# Submitted batch job 59220
# Submitted batch job 59221
# Submitted batch job 59222
# Submitted batch job 59223
# Submitted batch job 59224
# Submitted batch job 59225
# Submitted batch job 59226
# Submitted batch job 59227
# Submitted batch job 59228
# Submitted batch job 59229
# Submitted batch job 59230
# Submitted batch job 59231
# Submitted batch job 59232
# Submitted batch job 59233
# Submitted batch job 59234
# Submitted batch job 59235
# Submitted batch job 59236
# Submitted batch job 59237
# Submitted batch job 59238
# Submitted batch job 59239
# Submitted batch job 59240
# Submitted batch job 59241
# Submitted batch job 59242
# Submitted batch job 59243
# Submitted batch job 59244
# Submitted batch job 59245
# Submitted batch job 59246
# Submitted batch job 59247
# Submitted batch job 59248
# Submitted batch job 59249
# Submitted batch job 59250
# Submitted batch job 59251
# Submitted batch job 59252
# Submitted batch job 59253
# Submitted batch job 59254
# Submitted batch job 59255
# Submitted batch job 59256
# Submitted batch job 59257
# Submitted batch job 59258
# Submitted batch job 59259
# Submitted batch job 59260
# Submitted batch job 59261
# Submitted batch job 59262
# Submitted batch job 59263
# Submitted batch job 59264
# Submitted batch job 59265
# Submitted batch job 59266
# Submitted batch job 59267
# Submitted batch job 59268
# Submitted batch job 59269
# Submitted batch job 59270
# Submitted batch job 59271
# Submitted batch job 59272
# Submitted batch job 59273
# Submitted batch job 59274
# Submitted batch job 59275
# Submitted batch job 59276
# Submitted batch job 59277
# Submitted batch job 59278
# Submitted batch job 59279
# Submitted batch job 59280
# Submitted batch job 59281
# Submitted batch job 59282
# Submitted batch job 59283
# Submitted batch job 59284
# Submitted batch job 59285
# Submitted batch job 59286
# Submitted batch job 59287
# Submitted batch job 59288
# Submitted batch job 59289
# Submitted batch job 59290
# Submitted batch job 59291
# Submitted batch job 59292
# Submitted batch job 59293
# Submitted batch job 59294
# Submitted batch job 59295
# Submitted batch job 59296
# Submitted batch job 59297
# Submitted batch job 59298
# Submitted batch job 59299
# Submitted batch job 59300
# Submitted batch job 59301
# Submitted batch job 59302
# Submitted batch job 59303
# Submitted batch job 59304
# Submitted batch job 59305
# Submitted batch job 59306
# Submitted batch job 59307
# Submitted batch job 59308
# Submitted batch job 59309
# Submitted batch job 59310
# Submitted batch job 59311
# Submitted batch job 59312
# Submitted batch job 59313
# Submitted batch job 59314
# Submitted batch job 59315
# Submitted batch job 59316
# Submitted batch job 59317
# Submitted batch job 59318
# Submitted batch job 59319
# Submitted batch job 59320
# Submitted batch job 59321
# Submitted batch job 59322
# Submitted batch job 59323
# Submitted batch job 59324
# Submitted batch job 59325
# Submitted batch job 59326
# Submitted batch job 59327
# Submitted batch job 59328
# Submitted batch job 59329
# Submitted batch job 59330
# Submitted batch job 59331
# Submitted batch job 59332
# Submitted batch job 59333
# Submitted batch job 59334
# Submitted batch job 59335
# Submitted batch job 59336
# Submitted batch job 59337
# Submitted batch job 59338
# Submitted batch job 59339
# Submitted batch job 59340
# Submitted batch job 59341
# Submitted batch job 59342
# Submitted batch job 59343
# Submitted batch job 59344
# Submitted batch job 59345
# Submitted batch job 59346
# Submitted batch job 59347
# Submitted batch job 59348
# Submitted batch job 59349
# Submitted batch job 59350
# Submitted batch job 59351
# Submitted batch job 59352
# Submitted batch job 59353
# Submitted batch job 59354
# Submitted batch job 59355
# Submitted batch job 59356
# Submitted batch job 59357
# Submitted batch job 59358
# Submitted batch job 59359
# Submitted batch job 59360
# Submitted batch job 59361
# Submitted batch job 59362
# Submitted batch job 59363
# Submitted batch job 59364
# Submitted batch job 59365
# Submitted batch job 59366
# Submitted batch job 59367
# Submitted batch job 59368
# Submitted batch job 59369
# Submitted batch job 59370
# Submitted batch job 59371
# Submitted batch job 59372
# Submitted batch job 59373
# Submitted batch job 59374
# Submitted batch job 59375
# Submitted batch job 59376
# Submitted batch job 59377
# Submitted batch job 59378
# Submitted batch job 59379
# Submitted batch job 59380
# Submitted batch job 59381
# Submitted batch job 59382
# Submitted batch job 59383
# Submitted batch job 59384
# Submitted batch job 59385
# Submitted batch job 59386
# Submitted batch job 59387
# Submitted batch job 59388
# Submitted batch job 59389
# Submitted batch job 59390
# Submitted batch job 59391
# Submitted batch job 59392
# Submitted batch job 59393
# Submitted batch job 59394
# Submitted batch job 59395
# Submitted batch job 59396
# Submitted batch job 59397
# Submitted batch job 59398
# Submitted batch job 59399
# Submitted batch job 59400
# Submitted batch job 59401
# Submitted batch job 59402
# Submitted batch job 59403
# Submitted batch job 59404
# Submitted batch job 59405
# Submitted batch job 59406
# Submitted batch job 59407
# Submitted batch job 59408
# Submitted batch job 59409
# Submitted batch job 59410
# Submitted batch job 59411
# Submitted batch job 59412
# Submitted batch job 59413
# Submitted batch job 59414
# Submitted batch job 59415
# Submitted batch job 59416
# Submitted batch job 59417
# Submitted batch job 59418
# Submitted batch job 59419
# Submitted batch job 59420
# Submitted batch job 59421
# Submitted batch job 59422
# Submitted batch job 59423
# Submitted batch job 59424
# Submitted batch job 59425
# Submitted batch job 59426
# Submitted batch job 59427
# Submitted batch job 59428
# Submitted batch job 59429
# Submitted batch job 59430
# Submitted batch job 59431
# Submitted batch job 59432
# Submitted batch job 59433
# Submitted batch job 59434
# Submitted batch job 59435
# Submitted batch job 59436
# Submitted batch job 59437
# Submitted batch job 59438
# Submitted batch job 59439
# Submitted batch job 59440
# Submitted batch job 59441
# Submitted batch job 59442
# Submitted batch job 59443
# Submitted batch job 59444
# Submitted batch job 59445
# Submitted batch job 59446
# Submitted batch job 59447
# Submitted batch job 59448
# Submitted batch job 59449
# Submitted batch job 59450
# Submitted batch job 59451
# Submitted batch job 59452
# Submitted batch job 59453
# Submitted batch job 59454
# Submitted batch job 59455
# Submitted batch job 59456
# Submitted batch job 59457
# Submitted batch job 59458
# Submitted batch job 59459
# Submitted batch job 59460
# Submitted batch job 59461
# Submitted batch job 59462
# Submitted batch job 59463
# Submitted batch job 59464
# Submitted batch job 59465
# Submitted batch job 59466
# Submitted batch job 59467
# Submitted batch job 59468
# Submitted batch job 59469
# Submitted batch job 59470
# Submitted batch job 59471
# Submitted batch job 59472
# Submitted batch job 59473
# Submitted batch job 59474
# Submitted batch job 59475
# Submitted batch job 59476
# Submitted batch job 59477
# Submitted batch job 59478
# Submitted batch job 59479
# Submitted batch job 59480
# Submitted batch job 59481
# Submitted batch job 59482
# Submitted batch job 59483
# Submitted batch job 59484
# Submitted batch job 59485
# Submitted batch job 59486
# Submitted batch job 59487
# Submitted batch job 59488
# Submitted batch job 59489
# Submitted batch job 59490
# Submitted batch job 59491
# Submitted batch job 59492
# Submitted batch job 59493
# Submitted batch job 59494
# Submitted batch job 59495
# Submitted batch job 59496
# Submitted batch job 59497
# Submitted batch job 59498
# Submitted batch job 59499
# Submitted batch job 59500
# Submitted batch job 59501
# Submitted batch job 59502
# Submitted batch job 59503
# Submitted batch job 59504
# Submitted batch job 59505
# Submitted batch job 59506
# Submitted batch job 59507
# Submitted batch job 59508
# Submitted batch job 59509
# Submitted batch job 59510
# Submitted batch job 59511
# Submitted batch job 59512
# Submitted batch job 59513
# Submitted batch job 59514
# Submitted batch job 59515
# Submitted batch job 59516
# Submitted batch job 59517
# Submitted batch job 59518
# Submitted batch job 59519
# Submitted batch job 59520
# Submitted batch job 59521
# Submitted batch job 59522
# Submitted batch job 59523
# Submitted batch job 59524
# Submitted batch job 59525
# Submitted batch job 59526
# Submitted batch job 59527
# Submitted batch job 59528
# Submitted batch job 59529
# Submitted batch job 59530
# Submitted batch job 59531
# Submitted batch job 59532
# Submitted batch job 59533
# Submitted batch job 59534
# Submitted batch job 59535
# Submitted batch job 59536
# Submitted batch job 59537
# Submitted batch job 59538
# Submitted batch job 59539
# Submitted batch job 59540
# Submitted batch job 59541
# Submitted batch job 59542
# Submitted batch job 59543
# Submitted batch job 59544
# Submitted batch job 59545
# Submitted batch job 59546
# Submitted batch job 59547
# Submitted batch job 59548
# Submitted batch job 59549
# Submitted batch job 59550
# Submitted batch job 59551
# Submitted batch job 59552
# Submitted batch job 59553
# Submitted batch job 59554
# Submitted batch job 59555
# Submitted batch job 59556
# Submitted batch job 59557
# Submitted batch job 59558
# Submitted batch job 59559
# Submitted batch job 59560
# Submitted batch job 59561
# Submitted batch job 59562
# Submitted batch job 59563
# Submitted batch job 59564
# Submitted batch job 59565
# Submitted batch job 59566
# Submitted batch job 59567
# Submitted batch job 59568
# Submitted batch job 59569
# Submitted batch job 59570
# Submitted batch job 59571
# Submitted batch job 59572
# Submitted batch job 59573
# Submitted batch job 59574
# Submitted batch job 59575
# Submitted batch job 59576
# Submitted batch job 59577
# Submitted batch job 59578
# Submitted batch job 59579
# Submitted batch job 59580
# Submitted batch job 59581
# Submitted batch job 59582
# Submitted batch job 59583
# Submitted batch job 59584
# Submitted batch job 59585
# Submitted batch job 59586
# Submitted batch job 59587
# Submitted batch job 59588
# Submitted batch job 59589
# Submitted batch job 59590
# Submitted batch job 59591
# Submitted batch job 59592
# Submitted batch job 59593
# Submitted batch job 59594
# Submitted batch job 59595
# Submitted batch job 59596
# Submitted batch job 59597
# Submitted batch job 59598
# Submitted batch job 59599
# Submitted batch job 59600
# Submitted batch job 59601
# Submitted batch job 59602
# Submitted batch job 59603
# Submitted batch job 59604
# Submitted batch job 59605
# Submitted batch job 59606
# Submitted batch job 59607
# Submitted batch job 59608
# Submitted batch job 59609
# Submitted batch job 59610
# Submitted batch job 59611
# Submitted batch job 59612
# Submitted batch job 59613
# Submitted batch job 59614
# Submitted batch job 59615
# Submitted batch job 59616
# Submitted batch job 59617
# Submitted batch job 59618
# Submitted batch job 59619
# Submitted batch job 59620
# Submitted batch job 59621
# Submitted batch job 59622
# Submitted batch job 59623
# Submitted batch job 59624
# Submitted batch job 59625
# Submitted batch job 59626
# Submitted batch job 59627
# Submitted batch job 59628
# Submitted batch job 59629
# Submitted batch job 59630
# Submitted batch job 59631
# Submitted batch job 59632
# Submitted batch job 59633
# Submitted batch job 59634
# Submitted batch job 59635
# Submitted batch job 59636
# Submitted batch job 59637
# Submitted batch job 59638
# Submitted batch job 59639
# Submitted batch job 59640
# Submitted batch job 59641
# Submitted batch job 59642
# Submitted batch job 59643
# Submitted batch job 59644
# Submitted batch job 59645
# Submitted batch job 59646
# Submitted batch job 59647
# Submitted batch job 59648
# Submitted batch job 59649
# Submitted batch job 59650
# Submitted batch job 59651
# Submitted batch job 59652
# Submitted batch job 59653
# Submitted batch job 59654
# Submitted batch job 59655
# Submitted batch job 59656
# Submitted batch job 59657
# Submitted batch job 59658
# Submitted batch job 59659
# Submitted batch job 59660
# Submitted batch job 59661
# Submitted batch job 59662
# Submitted batch job 59663
# Submitted batch job 59664
# Submitted batch job 59665
# Submitted batch job 59666
# Submitted batch job 59667
# Submitted batch job 59668
# Submitted batch job 59669
# Submitted batch job 59670
# Submitted batch job 59671
# Submitted batch job 59672
# Submitted batch job 59673
# Submitted batch job 59674
# Submitted batch job 59675
# Submitted batch job 59676
# Submitted batch job 59677
# Submitted batch job 59678
# Submitted batch job 59679
# Submitted batch job 59680
# Submitted batch job 59681
# Submitted batch job 59682
# Submitted batch job 59683
# Submitted batch job 59684
# Submitted batch job 59685
# Submitted batch job 59686
# Submitted batch job 59687
# Submitted batch job 59688
# Submitted batch job 59689
# Submitted batch job 59690
# Submitted batch job 59691
# Submitted batch job 59692
# Submitted batch job 59693
# Submitted batch job 59694
# Submitted batch job 59695
# Submitted batch job 59696
# Submitted batch job 59697
# Submitted batch job 59698
# Submitted batch job 59699
# Submitted batch job 59700
# Submitted batch job 59701
# Submitted batch job 59702
# Submitted batch job 59703
# Submitted batch job 59704
# Submitted batch job 59705
# Submitted batch job 59706
# Submitted batch job 59707
# Submitted batch job 59708
# Submitted batch job 59709
# Submitted batch job 59710
# Submitted batch job 59711
# Submitted batch job 59712
# Submitted batch job 59713
# Submitted batch job 59714
# Submitted batch job 59715
# Submitted batch job 59716
# Submitted batch job 59717
# Submitted batch job 59718
# Submitted batch job 59719
# Submitted batch job 59720
# Submitted batch job 59721
# Submitted batch job 59722
# Submitted batch job 59723
# Submitted batch job 59724
# Submitted batch job 59725
# Submitted batch job 59726
# Submitted batch job 59727
# Submitted batch job 59728
# Submitted batch job 59729
# Submitted batch job 59730
# Submitted batch job 59731
# Submitted batch job 59732
# Submitted batch job 59733
# Submitted batch job 59734
# Submitted batch job 59735
# Submitted batch job 59736
# Submitted batch job 59737
# Submitted batch job 59738
# Submitted batch job 59739
# Submitted batch job 59740
# Submitted batch job 59741
# Submitted batch job 59742
# Submitted batch job 59743
# Submitted batch job 59744
# Submitted batch job 59745
# Submitted batch job 59746
# Submitted batch job 59747
# Submitted batch job 59748
# Submitted batch job 59749
# Submitted batch job 59750
# Submitted batch job 59751
# Submitted batch job 59752
# Submitted batch job 59753
# Submitted batch job 59754
# Submitted batch job 59755
# Submitted batch job 59756
# Submitted batch job 59757
# Submitted batch job 59758
# Submitted batch job 59759
# Submitted batch job 59760
# Submitted batch job 59761
# Submitted batch job 59762
# Submitted batch job 59763
# Submitted batch job 59764
# Submitted batch job 59765
# Submitted batch job 59766
# Submitted batch job 59767
# Submitted batch job 59768
# Submitted batch job 59769
# Submitted batch job 59770
# Submitted batch job 59771
# Submitted batch job 59772
# Submitted batch job 59773
# Submitted batch job 59774
# Submitted batch job 59775
# Submitted batch job 59776
# Submitted batch job 59777
# Submitted batch job 59778
# Submitted batch job 59779
# Submitted batch job 59780
# Submitted batch job 59781
# Submitted batch job 59782
# Submitted batch job 59783
# Submitted batch job 59784
# Submitted batch job 59785
# Submitted batch job 59786
# Submitted batch job 59787
# Submitted batch job 59788
# Submitted batch job 59789
# Submitted batch job 59790
# Submitted batch job 59791
# Submitted batch job 59792
# Submitted batch job 59793
# Submitted batch job 59794
# Submitted batch job 59795
# Submitted batch job 59796
# Submitted batch job 59797
# Submitted batch job 59798
# Submitted batch job 59799
# Submitted batch job 59800
# Submitted batch job 59801
# Submitted batch job 59802
# Submitted batch job 59803
# Submitted batch job 59804
# Submitted batch job 59805
# Submitted batch job 59806
# Submitted batch job 59807
# Submitted batch job 59808
# Submitted batch job 59809
# Submitted batch job 59810
# Submitted batch job 59811
# Submitted batch job 59812
# Submitted batch job 59813
# Submitted batch job 59814
# Submitted batch job 59815
# Submitted batch job 59816
# Submitted batch job 59817
# Submitted batch job 59818
# Submitted batch job 59819
# Submitted batch job 59820
# Submitted batch job 59821
# Submitted batch job 59822
# Submitted batch job 59823
# Submitted batch job 59824
# Submitted batch job 59825
# Submitted batch job 59826
# Submitted batch job 59827
# Submitted batch job 59828
# Submitted batch job 59829
# Submitted batch job 59830
# Submitted batch job 59831
# Submitted batch job 59832
# Submitted batch job 59833
# Submitted batch job 59834
# Submitted batch job 59835
# Submitted batch job 59836
# Submitted batch job 59837
# Submitted batch job 59838
# Submitted batch job 59839
# Submitted batch job 59840
# Submitted batch job 59841
# Submitted batch job 59842
# Submitted batch job 59843
# Submitted batch job 59844
# Submitted batch job 59845
# Submitted batch job 59846
# Submitted batch job 59847
# Submitted batch job 59848
# Submitted batch job 59849
# Submitted batch job 59850
# Submitted batch job 59851
# Submitted batch job 59852
# Submitted batch job 59853
# Submitted batch job 59854
# Submitted batch job 59855
# Submitted batch job 59856
# Submitted batch job 59857
# Submitted batch job 59858
# Submitted batch job 59859
# Submitted batch job 59860
# Submitted batch job 59861
# Submitted batch job 59862
# Submitted batch job 59863
# Submitted batch job 59864
# Submitted batch job 59865
# Submitted batch job 59866
# Submitted batch job 59867
# Submitted batch job 59868
# Submitted batch job 59869
# Submitted batch job 59870
# Submitted batch job 59871
# Submitted batch job 59872
# Submitted batch job 59873
# Submitted batch job 59874
# Submitted batch job 59875
# Submitted batch job 59876
# Submitted batch job 59877
# Submitted batch job 59878
# Submitted batch job 59879
# Submitted batch job 59880
# Submitted batch job 59881
# Submitted batch job 59882
# Submitted batch job 59883
# Submitted batch job 59884
# Submitted batch job 59885
# Submitted batch job 59886
# Submitted batch job 59887
# Submitted batch job 59888
# Submitted batch job 59889
# Submitted batch job 59890
# Submitted batch job 59891
# Submitted batch job 59892
# Submitted batch job 59893
# Submitted batch job 59894
# Submitted batch job 59895
# Submitted batch job 59896
# Submitted batch job 59897
# Submitted batch job 59898
# Submitted batch job 59899
# Submitted batch job 59900
# Submitted batch job 59901
# Submitted batch job 59902
# Submitted batch job 59903
# Submitted batch job 59904
# Submitted batch job 59905
# Submitted batch job 59906
# Submitted batch job 59907
# Submitted batch job 59908
# Submitted batch job 59909
# Submitted batch job 59910
# Submitted batch job 59911
# Submitted batch job 59912
# Submitted batch job 59913
# Submitted batch job 59914
# Submitted batch job 59915
# Submitted batch job 59916
# Submitted batch job 59917
# Submitted batch job 59918
# Submitted batch job 59919
# Submitted batch job 59920
# Submitted batch job 59921
# Submitted batch job 59922
# Submitted batch job 59923
# Submitted batch job 59924
# Submitted batch job 59925
# Submitted batch job 59926
# Submitted batch job 59927
# Submitted batch job 59928
# Submitted batch job 59929
# Submitted batch job 59930
# Submitted batch job 59931
# Submitted batch job 59932
# Submitted batch job 59933
# Submitted batch job 59934
# Submitted batch job 59935
# Submitted batch job 59936
# Submitted batch job 59937
# Submitted batch job 59938
# Submitted batch job 59939
# Submitted batch job 59940
# Submitted batch job 59941
# Submitted batch job 59942
# Submitted batch job 59943
# Submitted batch job 59944
# Submitted batch job 59945
# Submitted batch job 59946
# Submitted batch job 59947
# Submitted batch job 59948
# Submitted batch job 59949
# Submitted batch job 59950
# Submitted batch job 59951
# Submitted batch job 59952
# Submitted batch job 59953
# Submitted batch job 59954
# Submitted batch job 59955
# Submitted batch job 59956
# Submitted batch job 59957
# Submitted batch job 59958
# Submitted batch job 59959
# Submitted batch job 59960
# Submitted batch job 59961
# Submitted batch job 59962
# Submitted batch job 59963
# Submitted batch job 59964
# Submitted batch job 59965
# Submitted batch job 59966
# Submitted batch job 59967
# Submitted batch job 59968
# Submitted batch job 59969
# Submitted batch job 59970
# Submitted batch job 59971
# Submitted batch job 59972
# Submitted batch job 59973
# Submitted batch job 59974
# Submitted batch job 59975
# Submitted batch job 59976
# Submitted batch job 59977
# Submitted batch job 59978
# Submitted batch job 59979
# Submitted batch job 59980
# Submitted batch job 59981
# Submitted batch job 59982
# Submitted batch job 59983
# Submitted batch job 59984
# Submitted batch job 59985
# Submitted batch job 59986
# Submitted batch job 59987
# Submitted batch job 59988
# Submitted batch job 59989
# Submitted batch job 59990
# Submitted batch job 59991
# Submitted batch job 59992
# Submitted batch job 59993
# Submitted batch job 59994
# Submitted batch job 59995
# Submitted batch job 59996
# Submitted batch job 59997
# Submitted batch job 59998
# Submitted batch job 59999
# Submitted batch job 60000
# Submitted batch job 60001
# Submitted batch job 60002
# Submitted batch job 60003
# Submitted batch job 60004
# Submitted batch job 60005
# Submitted batch job 60006
# Submitted batch job 60007
# Submitted batch job 60008
# Submitted batch job 60009
# Submitted batch job 60010
# Submitted batch job 60011
# Submitted batch job 60012
# Submitted batch job 60013
# Submitted batch job 60014
# Submitted batch job 60015
# Submitted batch job 60016
# Submitted batch job 60017
# Submitted batch job 60018
# Submitted batch job 60019
# Submitted batch job 60020
# Submitted batch job 60021
# Submitted batch job 60022
# Submitted batch job 60023
# Submitted batch job 60024
# Submitted batch job 60025
# Submitted batch job 60026
# Submitted batch job 60027
# Submitted batch job 60028
# Submitted batch job 60029
# Submitted batch job 60030
# Submitted batch job 60031
# Submitted batch job 60032
# Submitted batch job 60033
# Submitted batch job 60034
# Submitted batch job 60035
# Submitted batch job 60036
# Submitted batch job 60037
# Submitted batch job 60038
# Submitted batch job 60039
# Submitted batch job 60040
# Submitted batch job 60041
# Submitted batch job 60042
# Submitted batch job 60043
# Submitted batch job 60044
# Submitted batch job 60045
# Submitted batch job 60046
# Submitted batch job 60047
# Submitted batch job 60048
# Submitted batch job 60049
# Submitted batch job 60050
# Submitted batch job 60051
# Submitted batch job 60052
# Submitted batch job 60053
# Submitted batch job 60054
# Submitted batch job 60055
# Submitted batch job 60056
# Submitted batch job 60057
# Submitted batch job 60058
# Submitted batch job 60059
# Submitted batch job 60060
# Submitted batch job 60061
# Submitted batch job 60062
# Submitted batch job 60063
# Submitted batch job 60064
# Submitted batch job 60065
# Submitted batch job 60066
# Submitted batch job 60067
# Submitted batch job 60068
# Submitted batch job 60069
# Submitted batch job 60070
# Submitted batch job 60071
# Submitted batch job 60072
# Submitted batch job 60073
# Submitted batch job 60074
# Submitted batch job 60075
# Submitted batch job 60076
# Submitted batch job 60077
# Submitted batch job 60078
# Submitted batch job 60079
# Submitted batch job 60080
# Submitted batch job 60081
# Submitted batch job 60082
# Submitted batch job 60083
# Submitted batch job 60084
# Submitted batch job 60085
# Submitted batch job 60086
# Submitted batch job 60087
# Submitted batch job 60088
# Submitted batch job 60089
# Submitted batch job 60090
# Submitted batch job 60091
# Submitted batch job 60092
# Submitted batch job 60093
# Submitted batch job 60094
# Submitted batch job 60095
# Submitted batch job 60096
# Submitted batch job 60097
# Submitted batch job 60098
# Submitted batch job 60099
# Submitted batch job 60100
# Submitted batch job 60101
# Submitted batch job 60102
# Submitted batch job 60103
# Submitted batch job 60104
# Submitted batch job 60105
# Submitted batch job 60106
# Submitted batch job 60107
# Submitted batch job 60108
# Submitted batch job 60109
# Submitted batch job 60110
# Submitted batch job 60111
# Submitted batch job 60112
# Submitted batch job 60113
# Submitted batch job 60114
# Submitted batch job 60115
# Submitted batch job 60116
# Submitted batch job 60117
# Submitted batch job 60118
# Submitted batch job 60119
# Submitted batch job 60120
# Submitted batch job 60121
# Submitted batch job 60122
# Submitted batch job 60123
# Submitted batch job 60124
# Submitted batch job 60125
# Submitted batch job 60126
# Submitted batch job 60127
# Submitted batch job 60128
# Submitted batch job 60129
# Submitted batch job 60130
# Submitted batch job 60131
# Submitted batch job 60132
# Submitted batch job 60133
# Submitted batch job 60134
# Submitted batch job 60135
# Submitted batch job 60136
# Submitted batch job 60137
# Submitted batch job 60138
# Submitted batch job 60139
# Submitted batch job 60140
# Submitted batch job 60141
# Submitted batch job 60142
# Submitted batch job 60143
# Submitted batch job 60144
# Submitted batch job 60145
# Submitted batch job 60146
# Submitted batch job 60147
# Submitted batch job 60148
# Submitted batch job 60149
# Submitted batch job 60150
# Submitted batch job 60151
# Submitted batch job 60152
# Submitted batch job 60153
# Submitted batch job 60154
# Submitted batch job 60155
# Submitted batch job 60156
# Submitted batch job 60157
# Submitted batch job 60158
# Submitted batch job 60159
# Submitted batch job 60160
# Submitted batch job 60161
# Submitted batch job 60162
# Submitted batch job 60163
# Submitted batch job 60164
# Submitted batch job 60165
# Submitted batch job 60166
# Submitted batch job 60167
# Submitted batch job 60168
# Submitted batch job 60169
# Submitted batch job 60170
# Submitted batch job 60171
# Submitted batch job 60172
# Submitted batch job 60173
# Submitted batch job 60174
# Submitted batch job 60175
# Submitted batch job 60176
# Submitted batch job 60177
# Submitted batch job 60178
# Submitted batch job 60179
# Submitted batch job 60180
# Submitted batch job 60181
# Submitted batch job 60182
# Submitted batch job 60183
# Submitted batch job 60184
# Submitted batch job 60185
# Submitted batch job 60186
# Submitted batch job 60187
# Submitted batch job 60188
# Submitted batch job 60189
# Submitted batch job 60190
# Submitted batch job 60191
# Submitted batch job 60192
# Submitted batch job 60193
# Submitted batch job 60194
# Submitted batch job 60195
# Submitted batch job 60196
# Submitted batch job 60197
# Submitted batch job 60198
# Submitted batch job 60199
# Submitted batch job 60200
# Submitted batch job 60201
# Submitted batch job 60202
# Submitted batch job 60203
# Submitted batch job 60204
# Submitted batch job 60205
# Submitted batch job 60206
# Submitted batch job 60207
# Submitted batch job 60208
# Submitted batch job 60209
# Submitted batch job 60210
# Submitted batch job 60211
# Submitted batch job 60212
# Submitted batch job 60213
# Submitted batch job 60214
# Submitted batch job 60215
# Submitted batch job 60216
# Submitted batch job 60217
# Submitted batch job 60218
# Submitted batch job 60219
# Submitted batch job 60220
# Submitted batch job 60221
# Submitted batch job 60222
# Submitted batch job 60223
# Submitted batch job 60224
# Submitted batch job 60225
# Submitted batch job 60226
# Submitted batch job 60227
# Submitted batch job 60228
# Submitted batch job 60229
# Submitted batch job 60230
# Submitted batch job 60231
# Submitted batch job 60232
# Submitted batch job 60233
# Submitted batch job 60234
# Submitted batch job 60235
# Submitted batch job 60236
# Submitted batch job 60237
# Submitted batch job 60238
# Submitted batch job 60239
# Submitted batch job 60240
# Submitted batch job 60241
# Submitted batch job 60242
# Submitted batch job 60243
# Submitted batch job 60244
# Submitted batch job 60245
# Submitted batch job 60246
# Submitted batch job 60247
# Submitted batch job 60248
# Submitted batch job 60249
# Submitted batch job 60250
# Submitted batch job 60251
# Submitted batch job 60252
# Submitted batch job 60253
# Submitted batch job 60254
# Submitted batch job 60255
# Submitted batch job 60256
# Submitted batch job 60257
# Submitted batch job 60258
# Submitted batch job 60259
# Submitted batch job 60260
# Submitted batch job 60261
# Submitted batch job 60262
# Submitted batch job 60263
# Submitted batch job 60264
# Submitted batch job 60265
# Submitted batch job 60266
# Submitted batch job 60267
# Submitted batch job 60268
# Submitted batch job 60269
# Submitted batch job 60270
# Submitted batch job 60271
# Submitted batch job 60272
# Submitted batch job 60273
# Submitted batch job 60274
# Submitted batch job 60275
# Submitted batch job 60276
# Submitted batch job 60277
# Submitted batch job 60278
# Submitted batch job 60279
# Submitted batch job 60280
# Submitted batch job 60281
# Submitted batch job 60282
# Submitted batch job 60283
# Submitted batch job 60284
# Submitted batch job 60285
# Submitted batch job 60286
# Submitted batch job 60287
# Submitted batch job 60288
# Submitted batch job 60289
# Submitted batch job 60290
# Submitted batch job 60291
# Submitted batch job 60292
# Submitted batch job 60293
# Submitted batch job 60294
# Submitted batch job 60295
# Submitted batch job 60296
# Submitted batch job 60297
# Submitted batch job 60298
# Submitted batch job 60299
# Submitted batch job 60300
# Submitted batch job 60301
# Submitted batch job 60302
# Submitted batch job 60303
# Submitted batch job 60304
# Submitted batch job 60305
# Submitted batch job 60306
# Submitted batch job 60307
# Submitted batch job 60308
# Submitted batch job 60309
# Submitted batch job 60310
# Submitted batch job 60311
# Submitted batch job 60312
# Submitted batch job 60313
# Submitted batch job 60314
# Submitted batch job 60315
# Submitted batch job 60316
# Submitted batch job 60317
# Submitted batch job 60318
# Submitted batch job 60319
# Submitted batch job 60320
# Submitted batch job 60321
# Submitted batch job 60322
# Submitted batch job 60323
# Submitted batch job 60324
# Submitted batch job 60325
# Submitted batch job 60326
# Submitted batch job 60327
# Submitted batch job 60328
# Submitted batch job 60329
# Submitted batch job 60330
# Submitted batch job 60331
# Submitted batch job 60332
# Submitted batch job 60333
# Submitted batch job 60334
# Submitted batch job 60335
# Submitted batch job 60336
# Submitted batch job 60337
# Submitted batch job 60338
# Submitted batch job 60339
# Submitted batch job 60340
# Submitted batch job 60341
# Submitted batch job 60342
# Submitted batch job 60343
# Submitted batch job 60344
# Submitted batch job 60345
# Submitted batch job 60346
# Submitted batch job 60347
# Submitted batch job 60348
# Submitted batch job 60349
# Submitted batch job 60350
# Submitted batch job 60351
# Submitted batch job 60352
# Submitted batch job 60353
# Submitted batch job 60354
# Submitted batch job 60355
# Submitted batch job 60356
# Submitted batch job 60357
# Submitted batch job 60358
# Submitted batch job 60359
# Submitted batch job 60360
# Submitted batch job 60361
# Submitted batch job 60362
# Submitted batch job 60363
# Submitted batch job 60364
# Submitted batch job 60365
# Submitted batch job 60366
# Submitted batch job 60367
# Submitted batch job 60368
# Submitted batch job 60369
# Submitted batch job 60370
# Submitted batch job 60371
# Submitted batch job 60372
# Submitted batch job 60373
# Submitted batch job 60374
# Submitted batch job 60375
# Submitted batch job 60376
# Submitted batch job 60377
# Submitted batch job 60378
# Submitted batch job 60379
# Submitted batch job 60380
# Submitted batch job 60381
# Submitted batch job 60382
# Submitted batch job 60383
# Submitted batch job 60384
# Submitted batch job 60385
# Submitted batch job 60386
# Submitted batch job 60387
# Submitted batch job 60388
# Submitted batch job 60389
# Submitted batch job 60390
# Submitted batch job 60391
# Submitted batch job 60392
# Submitted batch job 60393
# Submitted batch job 60394
# Submitted batch job 60395
# Submitted batch job 60396
# Submitted batch job 60397
# Submitted batch job 60398
# Submitted batch job 60399
# Submitted batch job 60400
# Submitted batch job 60401
# Submitted batch job 60402
# Submitted batch job 60403
# Submitted batch job 60404
# Submitted batch job 60405
# Submitted batch job 60406
# Submitted batch job 60407
# Submitted batch job 60408
# Submitted batch job 60409
# Submitted batch job 60410
# Submitted batch job 60411
# Submitted batch job 60412
# Submitted batch job 60413
# Submitted batch job 60414
# Submitted batch job 60415
# Submitted batch job 60416
# Submitted batch job 60417
# Submitted batch job 60418
# Submitted batch job 60419
# Submitted batch job 60420
# Submitted batch job 60421
# Submitted batch job 60422
# Submitted batch job 60423
# Submitted batch job 60424
# Submitted batch job 60425
# Submitted batch job 60426
# Submitted batch job 60427
# Submitted batch job 60428
# Submitted batch job 60429
# Submitted batch job 60430
# Submitted batch job 60431
# Submitted batch job 60432
# Submitted batch job 60433
# Submitted batch job 60434
# Submitted batch job 60435
# Submitted batch job 60436
# Submitted batch job 60437
# Submitted batch job 60438
# Submitted batch job 60439
# Submitted batch job 60440
# Submitted batch job 60441
# Submitted batch job 60442
# Submitted batch job 60443
# Submitted batch job 60444
# Submitted batch job 60445
# Submitted batch job 60446
# Submitted batch job 60447
# Submitted batch job 60448
# Submitted batch job 60449
# Submitted batch job 60450
# Submitted batch job 60451
# Submitted batch job 60452
# Submitted batch job 60453
# ...
# Submitted batch job 61143
# Submitted batch job 61144
# Submitted batch job 61145
# Submitted batch job 61146
# Submitted batch job 61147
# Submitted batch job 61148
# Submitted batch job 61149
# Submitted batch job 61150
# Submitted batch job 61151
# Submitted batch job 61152
# Submitted batch job 61153
# Submitted batch job 61154
# Submitted batch job 61155
# Submitted batch job 61156
# Submitted batch job 61157
# Submitted batch job 61158
# Submitted batch job 61159
# Submitted batch job 61160
# Submitted batch job 61161
# Submitted batch job 61162
# Submitted batch job 61163
# Submitted batch job 61164
# Submitted batch job 61165
# Submitted batch job 61166
# Submitted batch job 61167
# Submitted batch job 61168
# Submitted batch job 61169
# Submitted batch job 61170
# Submitted batch job 61171
# Submitted batch job 61172
# Submitted batch job 61173
# Submitted batch job 61174
# Submitted batch job 61175
# Submitted batch job 61176
# Submitted batch job 61177
# Submitted batch job 61178
# Submitted batch job 61179
# Submitted batch job 61180
# Submitted batch job 61181
# Submitted batch job 61182
# Submitted batch job 61183
# Submitted batch job 61184
# Submitted batch job 61185
# Submitted batch job 61186
# Submitted batch job 61187
# Submitted batch job 61188
# Submitted batch job 61189
# Submitted batch job 61190
# Submitted batch job 61191
# Submitted batch job 61192
# Submitted batch job 61193
# Submitted batch job 61194
# Submitted batch job 61195
# Submitted batch job 61196
# Submitted batch job 61197
# Submitted batch job 61198
# Submitted batch job 61199
# Submitted batch job 61200
# Submitted batch job 61201
# Submitted batch job 61202
# Submitted batch job 61203
# Submitted batch job 61204
# Submitted batch job 61205
# Submitted batch job 61206
# Submitted batch job 61207
# Submitted batch job 61208
# Submitted batch job 61209
# Submitted batch job 61210
# Submitted batch job 61211
# Submitted batch job 61212
# Submitted batch job 61213
# Submitted batch job 61214
# Submitted batch job 61215
# Submitted batch job 61216
# Submitted batch job 61217
# Submitted batch job 61218
# Submitted batch job 61219
# Submitted batch job 61220
# Submitted batch job 61221
# Submitted batch job 61222
# Submitted batch job 61223
# Submitted batch job 61224
# Submitted batch job 61225
# Submitted batch job 61226
# Submitted batch job 61227
# Submitted batch job 61228
# Submitted batch job 61229
# Submitted batch job 61230
# Submitted batch job 61231
# Submitted batch job 61232
# Submitted batch job 61233
# Submitted batch job 61234
# Submitted batch job 61235
# Submitted batch job 61236
# Submitted batch job 61237
# Submitted batch job 61238
# Submitted batch job 61239
# Submitted batch job 61240
# Submitted batch job 61241
# Submitted batch job 61242
# Submitted batch job 61243
# Submitted batch job 61244
# Submitted batch job 61245
# Submitted batch job 61246
# Submitted batch job 61247
# Submitted batch job 61248
# Submitted batch job 61249
# Submitted batch job 61250
# Submitted batch job 61251
# Submitted batch job 61252
# Submitted batch job 61253
# Submitted batch job 61254
# Submitted batch job 61255
# Submitted batch job 61256
# Submitted batch job 61257
# Submitted batch job 61258
# Submitted batch job 61259
# Submitted batch job 61260
# Submitted batch job 61261
# Submitted batch job 61262
# Submitted batch job 61263
# Submitted batch job 61264
# Submitted batch job 61265
# Submitted batch job 61266
# Submitted batch job 61267
# Submitted batch job 61268
# Submitted batch job 61269
# Submitted batch job 61270
# Submitted batch job 61271
# Submitted batch job 61272
# Submitted batch job 61273
# Submitted batch job 61274
# Submitted batch job 61275
# Submitted batch job 61276
# Submitted batch job 61277
# Submitted batch job 61278
# Submitted batch job 61279
# Submitted batch job 61280
# Submitted batch job 61281
# Submitted batch job 61282
# Submitted batch job 61283
# Submitted batch job 61284
# Submitted batch job 61285
# Submitted batch job 61286
# Submitted batch job 61287
# Submitted batch job 61288
# Submitted batch job 61289
# Submitted batch job 61290
# Submitted batch job 61291
# Submitted batch job 61292
# Submitted batch job 61293
# Submitted batch job 61294
# Submitted batch job 61295
# Submitted batch job 61296
# Submitted batch job 61297
# Submitted batch job 61298
# Submitted batch job 61299
# Submitted batch job 61300
# Submitted batch job 61301
# Submitted batch job 61302
# Submitted batch job 61303
# Submitted batch job 61304
# Submitted batch job 61305
# Submitted batch job 61306
# Submitted batch job 61307
# Submitted batch job 61308
# Submitted batch job 61309
# Submitted batch job 61310
# Submitted batch job 61311
# Submitted batch job 61312
# Submitted batch job 61313
# Submitted batch job 61314
# Submitted batch job 61315
# Submitted batch job 61316
# Submitted batch job 61317
# Submitted batch job 61318
# Submitted batch job 61319
# Submitted batch job 61320
# Submitted batch job 61321
# Submitted batch job 61322
# Submitted batch job 61323
# Submitted batch job 61324
# Submitted batch job 61325
# Submitted batch job 61326
# Submitted batch job 61327
# Submitted batch job 61328
# Submitted batch job 61329
# Submitted batch job 61330
# Submitted batch job 61331
# Submitted batch job 61332
# Submitted batch job 61333
# Submitted batch job 61334
# Submitted batch job 61335
# Submitted batch job 61336
# Submitted batch job 61337
# Submitted batch job 61338
# Submitted batch job 61339
# Submitted batch job 61340
# Submitted batch job 61341
# Submitted batch job 61342
# Submitted batch job 61343
# Submitted batch job 61344
# Submitted batch job 61345
# Submitted batch job 61346
# Submitted batch job 61347
# Submitted batch job 61348
# Submitted batch job 61349
# Submitted batch job 61350
# Submitted batch job 61351
# Submitted batch job 61352
# Submitted batch job 61353
# Submitted batch job 61354
# Submitted batch job 61355
# Submitted batch job 61356
# Submitted batch job 61357
# Submitted batch job 61358
# Submitted batch job 61359
# Submitted batch job 61360
# Submitted batch job 61361
# Submitted batch job 61362
# Submitted batch job 61363
# Submitted batch job 61364
# Submitted batch job 61365
# Submitted batch job 61366
# Submitted batch job 61367
# Submitted batch job 61368
# Submitted batch job 61369
# Submitted batch job 61370
# Submitted batch job 61371
# Submitted batch job 61372
# Submitted batch job 61373
# Submitted batch job 61374
# Submitted batch job 61375
# Submitted batch job 61376
# Submitted batch job 61377
# Submitted batch job 61378
# Submitted batch job 61379
# Submitted batch job 61380
# Submitted batch job 61381
# Submitted batch job 61382
# Submitted batch job 61383
# Submitted batch job 61384
# Submitted batch job 61385
# Submitted batch job 61386
# Submitted batch job 61387
# Submitted batch job 61388
# Submitted batch job 61389
# Submitted batch job 61390
# Submitted batch job 61391
# Submitted batch job 61392
# Submitted batch job 61393
# Submitted batch job 61394
# Submitted batch job 61395
# Submitted batch job 61396
# Submitted batch job 61397
# Submitted batch job 61398
# Submitted batch job 61399
# Submitted batch job 61400
# Submitted batch job 61401
# Submitted batch job 61402
# Submitted batch job 61403
# Submitted batch job 61404
# Submitted batch job 61405
# Submitted batch job 61406
# Submitted batch job 61407
# Submitted batch job 61408
# Submitted batch job 61409
# Submitted batch job 61410
# Submitted batch job 61411
# Submitted batch job 61412
# Submitted batch job 61413
# Submitted batch job 61414
# Submitted batch job 61415
# Submitted batch job 61416
# Submitted batch job 61417
# Submitted batch job 61418
# Submitted batch job 61419
# Submitted batch job 61420
# Submitted batch job 61421
# Submitted batch job 61422
# Submitted batch job 61423
# Submitted batch job 61424
# Submitted batch job 61425
# Submitted batch job 61426
# Submitted batch job 61427
# Submitted batch job 61428
# Submitted batch job 61429
# Submitted batch job 61430
# Submitted batch job 61431
# Submitted batch job 61432
# Submitted batch job 61433
# Submitted batch job 61434
# Submitted batch job 61435
# Submitted batch job 61436
# Submitted batch job 61437
# Submitted batch job 61438
# Submitted batch job 61439
# Submitted batch job 61440
# Submitted batch job 61441
# Submitted batch job 61442
# Submitted batch job 61443
# Submitted batch job 61444
# Submitted batch job 61445
# Submitted batch job 61446
# Submitted batch job 61447
# Submitted batch job 61448
# Submitted batch job 61449
# Submitted batch job 61450
# Submitted batch job 61451
# Submitted batch job 61452
# Submitted batch job 61453
# Submitted batch job 61454
# Submitted batch job 61455
# Submitted batch job 61456
# Submitted batch job 61457
# Submitted batch job 61458
# Submitted batch job 61459
# Submitted batch job 61460
# Submitted batch job 61461
# Submitted batch job 61462
# Submitted batch job 61463
# Submitted batch job 61464
# Submitted batch job 61465
# Submitted batch job 61466
# Submitted batch job 61467
# Submitted batch job 61468
# Submitted batch job 61469
# Submitted batch job 61470
# Submitted batch job 61471
# Submitted batch job 61472
# Submitted batch job 61473
# Submitted batch job 61474
# Submitted batch job 61475
# Submitted batch job 61476
# Submitted batch job 61477
# Submitted batch job 61478
# Submitted batch job 61479
# Submitted batch job 61480
# Submitted batch job 61481
# Submitted batch job 61482
# Submitted batch job 61483
# Submitted batch job 61484
# Submitted batch job 61485
# Submitted batch job 61486
# Submitted batch job 61487
# Submitted batch job 61488
# Submitted batch job 61489
# Submitted batch job 61490
# Submitted batch job 61491
# Submitted batch job 61492
# Submitted batch job 61493
# Submitted batch job 61494
# Submitted batch job 61495
# Submitted batch job 61496
# Submitted batch job 61497
# Submitted batch job 61498
# Submitted batch job 61499
# Submitted batch job 61500
# Submitted batch job 61501
# Submitted batch job 61502
# Submitted batch job 61503
# Submitted batch job 61504
# Submitted batch job 61505
# Submitted batch job 61506
# Submitted batch job 61507
# Submitted batch job 61508
# Submitted batch job 61509
# Submitted batch job 61510
# Submitted batch job 61511
# Submitted batch job 61512
# Submitted batch job 61513
# Submitted batch job 61514
# Submitted batch job 61515
# Submitted batch job 61516
# Submitted batch job 61517
# Submitted batch job 61518
# Submitted batch job 61519
# Submitted batch job 61520
# Submitted batch job 61521
# Submitted batch job 61522
# Submitted batch job 61523
# Submitted batch job 61524
# Submitted batch job 61525
# Submitted batch job 61526
# Submitted batch job 61527
# Submitted batch job 61528
# Submitted batch job 61529
# Submitted batch job 61530
# Submitted batch job 61531
# Submitted batch job 61532
# Submitted batch job 61533
# Submitted batch job 61534
# Submitted batch job 61535
# Submitted batch job 61536
# Submitted batch job 61537
# Submitted batch job 61538
# Submitted batch job 61539
# Submitted batch job 61540
# Submitted batch job 61541
# Submitted batch job 61542
# Submitted batch job 61543
# Submitted batch job 61544
# Submitted batch job 61545
# Submitted batch job 61546
# Submitted batch job 61547
# Submitted batch job 61548
# Submitted batch job 61549
# Submitted batch job 61550
# Submitted batch job 61551
# Submitted batch job 61552
# Submitted batch job 61553
# Submitted batch job 61554
# Submitted batch job 61555
# Submitted batch job 61556
# Submitted batch job 61557
# Submitted batch job 61558
# Submitted batch job 61559
# Submitted batch job 61560
# Submitted batch job 61561
# Submitted batch job 61562
# Submitted batch job 61563
# Submitted batch job 61564
# Submitted batch job 61565
# Submitted batch job 61566
# Submitted batch job 61567
# Submitted batch job 61568
# Submitted batch job 61569
# Submitted batch job 61570
# Submitted batch job 61571
# Submitted batch job 61572
# Submitted batch job 61573
# Submitted batch job 61574
# Submitted batch job 61575
# Submitted batch job 61576
# Submitted batch job 61577
# Submitted batch job 61578
# Submitted batch job 61579
# Submitted batch job 61580
# Submitted batch job 61581
# Submitted batch job 61582
# Submitted batch job 61583
# Submitted batch job 61584
# Submitted batch job 61585
# Submitted batch job 61586
# Submitted batch job 61587
# Submitted batch job 61588
# Submitted batch job 61589
# Submitted batch job 61590
# Submitted batch job 61591
# Submitted batch job 61592
# Submitted batch job 61593
# Submitted batch job 61594
# Submitted batch job 61595
# Submitted batch job 61596
# Submitted batch job 61597
# Submitted batch job 61598
# Submitted batch job 61599
# Submitted batch job 61600
# Submitted batch job 61601
# Submitted batch job 61602
# Submitted batch job 61603
# Submitted batch job 61604
# Submitted batch job 61605
# Submitted batch job 61606
# Submitted batch job 61607
# Submitted batch job 61608
# Submitted batch job 61609
# Submitted batch job 61610
# Submitted batch job 61611
# Submitted batch job 61612
# Submitted batch job 61613
# Submitted batch job 61614
# Submitted batch job 61615
# Submitted batch job 61616
# Submitted batch job 61617
# Submitted batch job 61618
# Submitted batch job 61619
# Submitted batch job 61620
# Submitted batch job 61621
# Submitted batch job 61622
# Submitted batch job 61623
# Submitted batch job 61624
# Submitted batch job 61625
# Submitted batch job 61626
# Submitted batch job 61627
# Submitted batch job 61628
# Submitted batch job 61629
# Submitted batch job 61630
# Submitted batch job 61631
# Submitted batch job 61632
# Submitted batch job 61633
# Submitted batch job 61634
# Submitted batch job 61635
# Submitted batch job 61636
# Submitted batch job 61637
# Submitted batch job 61638
# Submitted batch job 61639
# Submitted batch job 61640
# Submitted batch job 61641
# Submitted batch job 61642
# Submitted batch job 61643
# Submitted batch job 61644
# Submitted batch job 61645
# Submitted batch job 61646
# Submitted batch job 61647
# Submitted batch job 61648
# Submitted batch job 61649
# Submitted batch job 61650
# Submitted batch job 61651
# Submitted batch job 61652
# Submitted batch job 61653
# Submitted batch job 61654
# Submitted batch job 61655
# Submitted batch job 61656
# Submitted batch job 61657
# Submitted batch job 61658
# Submitted batch job 61659
# Submitted batch job 61660
# Submitted batch job 61661
# Submitted batch job 61662
# Submitted batch job 61663
# Submitted batch job 61664
# Submitted batch job 61665
# Submitted batch job 61666
# Submitted batch job 61667
# Submitted batch job 61668
# Submitted batch job 61669
# Submitted batch job 61670
# Submitted batch job 61671
# Submitted batch job 61672
# Submitted batch job 61673
# Submitted batch job 61674
# Submitted batch job 61675
# Submitted batch job 61676
# Submitted batch job 61677
# Submitted batch job 61678
# Submitted batch job 61679
# Submitted batch job 61680
# Submitted batch job 61681
# Submitted batch job 61682
# Submitted batch job 61683
# Submitted batch job 61684
# Submitted batch job 61685
# Submitted batch job 61686
# Submitted batch job 61687
# Submitted batch job 61688
# Submitted batch job 61689
# Submitted batch job 61690
# Submitted batch job 61691
# Submitted batch job 61692
# Submitted batch job 61693
# Submitted batch job 61694
# Submitted batch job 61695
# Submitted batch job 61696
# Submitted batch job 61697
# Submitted batch job 61698
# Submitted batch job 61699
# Submitted batch job 61700
# Submitted batch job 61701
# Submitted batch job 61702
# Submitted batch job 61703
# Submitted batch job 61704
# Submitted batch job 61705
# Submitted batch job 61706
# Submitted batch job 61707
# Submitted batch job 61708
# Submitted batch job 61709
# Submitted batch job 61710
# Submitted batch job 61711
# Submitted batch job 61712
# Submitted batch job 61713
# Submitted batch job 61714
# Submitted batch job 61715
# Submitted batch job 61716
# Submitted batch job 61717
# Submitted batch job 61718
# Submitted batch job 61719
# Submitted batch job 61720
# Submitted batch job 61721
# Submitted batch job 61722
# Submitted batch job 61723
# Submitted batch job 61724
# Submitted batch job 61725
# Submitted batch job 61726
# Submitted batch job 61727
# Submitted batch job 61728
# Submitted batch job 61729
# Submitted batch job 61730
# Submitted batch job 61731
# Submitted batch job 61732
# Submitted batch job 61733
# Submitted batch job 61734
# Submitted batch job 61735
# Submitted batch job 61736
# Submitted batch job 61737
# Submitted batch job 61738
# Submitted batch job 61739
# Submitted batch job 61740
# Submitted batch job 61741
# Submitted batch job 61742
# Submitted batch job 61743
# Submitted batch job 61744
# Submitted batch job 61745
# Submitted batch job 61746
# Submitted batch job 61747
# Submitted batch job 61748
# Submitted batch job 61749
# Submitted batch job 61750
# Submitted batch job 61751
# Submitted batch job 61752
# Submitted batch job 61753
# Submitted batch job 61754
# Submitted batch job 61755
# Submitted batch job 61756
# Submitted batch job 61757

# %%
for biovar in biovars:
    print(biovar)
    partitions_r = {}
    for i in range(len(partitions)):
        pickle_file_path = f'../baypass_lastgen/individual_gfiles_last_gen/loci_partition_{i}'
        with open(pickle_file_path, 'rb') as file:
            loci_f = pickle.load(file)
        results = pd.read_csv(f'results_{biovar}/partition{i}.csv')
        results['snp_id'] = loci_f
        partitions_r[i] = results

    results = pd.concat(partitions_r).reset_index(drop=True)
    
    results.to_csv(f'{biovar}_binomial_reg_results_last_gen.csv',index=None)
# Out:
# bio3
# bio4
# bio5
# bio6
# bio7
# bio8
# bio9
# bio10
# bio11
# bio13
# bio14
# bio15
# bio16
# bio17
# bio19

# %%
biovar = 'bio18'

# %%
loci_names = [file for file in files if 'loci' in file]

# %%
partition = 0

# %%
pickle_file_path = f'../baypass_lastgen/individual_gfiles_last_gen/loci_partition_{partition}'
with open(pickle_file_path, 'rb') as file:
    loci_f = pickle.load(file)

# %%
binomf = pd.read_csv(f'{biovar}_binomial_reg_results_last_gen.csv')

# %%
binomf = binom.sort_values('pvalue').head(100)

# %%
import pickle
dict_blocks = '../key_files/blocks_snpsid_dict.pkl'

with open(dict_blocks, 'rb') as file:
    dict_blocks = pickle.load(file)

reverse_mapping = {item: key for key, values in dict_blocks.items() for item in values}

# %%
binomf['block'] = binomf['snp_id'].map(reverse_mapping)

# %%
binomf = binomf.drop_duplicates('block')

# %%
biovar = 'bio18'

# %%
binomf.to_csv(f'top_hits_binom_last_gen_{biovar}.csv')

# %%
binomf
# Out:
#             slope         pvalue      snp_id   block
# 1019491  0.446543   0.000000e+00  5_23517896  5_2800
# 251289  -0.738521   0.000000e+00  1_27305725  1_4940
# 360788  -0.655283   0.000000e+00   2_9924439  2_1000
# 276924  -0.599578   0.000000e+00    2_258907    2_89
# 216154  -1.059550   0.000000e+00  1_24164130  1_4155
# 21230   -0.513580   0.000000e+00   1_2987541   1_360
# 265491  -0.471910   0.000000e+00  1_29200398  1_5115
# 727547  -0.869354   0.000000e+00  4_10274568  4_2042
# 161693  -0.776530   0.000000e+00  1_19426195  1_2697
# 751222  -1.058852   0.000000e+00  4_12571790  4_2552
# 862290  -0.486232   0.000000e+00   5_7722787   5_604
# 323344   0.460483   0.000000e+00   2_6018166   2_664
# 249333  -0.443393  6.816322e-309  1_27039188  1_4920

# %%
binom
# Out:
#             slope        pvalue      snp_id
# 0       -0.021596  6.688579e-02       1_346
# 1       -0.077940  1.952474e-04       1_353
# 2        0.125312  2.717472e-13       1_363
# 3       -0.494324  1.364982e-85       1_395
# 4       -0.494324  1.364982e-85       1_396
# ...           ...           ...         ...
# 1048630  0.281729  2.708040e-76  5_26975078
# 1048631 -0.081247  1.021719e-04  5_26975121
# 1048632 -0.081247  1.021719e-04  5_26975148
# 1048633 -0.029124  6.896039e-03  5_26975272
# 1048634  0.211876  6.716018e-56  5_26975288
#
# [1048635 rows x 3 columns]

# %%
len(results['snp_id'].unique())
# Out:
# 1048635

# %%
1048635 - 1048635
# Out:
# 0

# %%
len(results)
# Out:
# 1048635

# %%
all_loci = []
for i in loci_names:
    pickle_file_path = f'../baypass_lastgen/individual_gfiles_last_gen/{i}'
    with open(pickle_file_path, 'rb') as file:
        loci_f = pickle.load(file)
    all_loci.append(loci_f)

# %%
flattened_loci = [item for sublist in all_loci for item in sublist]

# %%
len(flattened_loci)
# Out:
# 1048635

# %%
biovar = 'bio18'

binom = pd.read_csv(f'{biovar}_binomial_reg_results_last_gen.csv')

binom['chrom'] = binom['snp_id'].str.split('_').str[0].astype(int)
binom['pos'] = binom['snp_id'].str.split('_').str[1].astype(int)

# %%
threshold_value = 0.05 / len(binom)

#sm.qqplot(pvalues['pvalue'], line ='45') 
#py.show() 

df = binom[['pvalue', 'pos', 'chrom']].copy()

colors = sns.color_palette("crest", n_colors = 5)

# Parsing chromosome number and position
df['chromosome'] = df['chrom']
df['position'] = df['pos']
df['-log10(pvalue)'] = -np.log10(df['pvalue'])

# Calculate the offset for each chromosome to prevent overlap
chromosome_offsets = {}
offset = 0
for chrom in sorted(df['chromosome'].unique()):
    chromosome_offsets[chrom] = offset
    max_position = df[df['chromosome'] == chrom]['position'].max()
    offset += max_position + 1000000  # Adding 1 million as a buffer between chromosomes

# Apply offsets to positions
df['adjusted_position'] = df.apply(lambda row: row['position'] + chromosome_offsets[row['chromosome']], axis=1)

# Creating the Manhattan plot
plt.figure(figsize=(20, 6))

for chrom in sorted(df['chromosome'].unique()):
    subset = df[df['chromosome'] == chrom]
    plt.scatter(subset['adjusted_position'], subset['-log10(pvalue)'], c=colors[chrom % len(colors)], label=f'Chr {chrom}', s=10)


#genes = ['2_199', '3_2730', '5_2244']
genes = ['1_19426350']
# Add circles around the specific genes
for gene in genes:
    chrom, pos = map(int, gene.split('_'))
    subset_gene = df[(df['chromosome'] == chrom) & (df['position'] == pos)]
    if not subset_gene.empty:
        plt.scatter(
            subset_gene['adjusted_position'],
            subset_gene['-log10(pvalue)'],
            edgecolor='red',  # Color of the edge of the circle
            linewidth=2,      # Width of the edge line
            facecolor='none', # Facecolor of the circle (None means transparent)
            s=100,            # Size of the circle
            label=f'Gene {gene}'
        )

    
# Aesthetics
plt.xlabel('Adjusted Position')
plt.ylabel('-log10(pvalue)')
#plt.title('Manhattan Plot')
#plt.grid(axis='y')
#plt.legend(title="Chromosome", bbox_to_anchor=(1.05, 1), loc='upper left')
ax = plt.gca()  # Get current axes
ax.spines['top'].set_visible(False)  # Remove the top spine
ax.spines['right'].set_visible(False)
# Threshold line (optional)
threshold = -np.log10(threshold_value)
plt.axhline(y=threshold, color='grey', linestyle='dashed')
plt.title(f'{biovar} Binomial GLM tau correlation')  # Set the title

# Show the plot
plt.tight_layout()
plt.savefig(f'manhattan_binom_{biovar}.png')
plt.show()
# Out:
# /home/tbellagio/miniforge3/envs/pipeline_snakemake/lib/python3.9/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /tmp/ipykernel_1205603/2443793408.py:31: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   plt.scatter(subset['adjusted_position'], subset['-log10(pvalue)'], c=colors[chrom % len(colors)], label=f'Chr {chrom}', s=10)

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
binom[binom['snp_id'].isin(dict_blocks['1_2697'])]
# Out:
#            slope         pvalue      snp_id
# 161689 -0.696014  8.405237e-121  1_19425748
# 161690  0.068115   3.996036e-03  1_19425815
# 161691  0.188093   5.229671e-26  1_19425821
# 161692 -0.067139   6.372973e-06  1_19425982
# 161693 -0.776530   0.000000e+00  1_19426195
# 161694 -0.678033  2.576877e-162  1_19426350

# %%
dict_blocks['1_2697']
# Out:
# ['1_19425693',
#  '1_19425731',
#  '1_19425748',
#  '1_19425815',
#  '1_19425821',
#  '1_19425837',
#  '1_19425841',
#  '1_19425889',
#  '1_19425911',
#  '1_19425923',
#  '1_19425930',
#  '1_19425982',
#  '1_19426016',
#  '1_19426040',
#  '1_19426043',
#  '1_19426049',
#  '1_19426073',
#  '1_19426081',
#  '1_19426095',
#  '1_19426152',
#  '1_19426195',
#  '1_19426206',
#  '1_19426291',
#  '1_19426350']
