# %%
import pandas as pd
import allel
import numpy as np
import seaborn as sns

# %%
snps_names = pd.read_csv('../key_files/var_pos_grenenet.csv')

import pickle
with open('../key_files/blocks_snpsid_dict.pkl', 'rb') as f:
    dict_blocks = pickle.load(f)

reverse_mapping = {item: key for key, values in dict_blocks.items() for item in values}

snps_names = snps_names[snps_names['total_alleles05filter_firstgen'].notna()].reset_index(drop=True)

# %%
clim1001 = pd.read_csv('../key_files/1001g_regmap_grenet_ecotype_info_corrected_bioclim_2024May16.csv')

clim1001['ecotypeid'] = clim1001['ecotypeid'].astype(str)

# %%
'../gwas/1001g/1001g_grenet_climate.recode.vcf'
# Out:
# '../gwas/1001g/1001g_grenet_climate.recode.vcf'

# %%
#vcfgrene = allel.read_vcf('../gwas/greneNet_final_v1.1.recode.vcf.gz')
vcfgrene = allel.read_vcf('../gwas/1001g/1001g_grenet_climate.recode.vcf')
geno = vcfgrene['calldata/GT']

geno = geno.sum(axis=2)

geno = pd.DataFrame(geno)

geno.columns = vcfgrene['samples']

grene_chrom_pos = pd.DataFrame({'chrom': vcfgrene['variants/CHROM'], 'pos': vcfgrene['variants/POS']})

#vcfgrene = pd.concat([grene_chrom_pos, geno],axis=1)

# %%
clim1001 = clim1001[clim1001['ecotypeid'].isin(geno.columns)]

# %%
clim1001 = clim1001[['ecotypeid', 'bio1']]

# %%
clim1001['ecotypeid'] = clim1001['ecotypeid'].astype(str)

# %%
clim1001_dict = clim1001.set_index('ecotypeid')['bio1'].to_dict()

# %%
len(clim1001_dict)
# Out:
# 1137

# %%
geno.columns
# Out:
# Index(['10001', '10002', '10004', '10005', '10006', '10008', '10009', '10010',
#        '10011', '10012',
#        ...
#        '9996', '9997', '9998', '9999', '100001', '100002', '6939', '9940',
#        '9977', '9992'],
#       dtype='object', length=1137)

# %%
clim1001 = clim1001.set_index('ecotypeid')

# %%
geno = geno.T

# %%
geno = geno.sort_index()

# %%
order_ecotypes = geno.index

# %%
clim1001 = clim1001.sort_index()

# %%
geno = geno.reset_index(drop=True)

# %%
clim1001 = clim1001.reset_index(drop=True)

# %%
geno_by_temp = geno.mul(np.array(clim1001), axis=1)

# %%
geno_by_temp.shape
# Out:
# (1137, 3235480)

# %%
231 * 2
# Out:
# 462

# %%
snp_origin = geno_by_temp.sum(axis=0) / 1137

# %%
snp_origin_bio1 = pd.DataFrame({'chrom': vcfgrene['variants/CHROM'], 'pos': vcfgrene['variants/POS'], 'snp_origin_bio1': snp_origin})

# %%
#snp_origin_bio1.to_csv('../key_files/snp_origin_bio1_1001gvcf.csv',index=None)

# %%
#grene_chrom_pos.sort_values('snp_origin_bio1')

# %%
#snp_origin_bio1.to_csv('../key_files/snp_origin_bio1_grenenetvcf.csv',index=None)

# %%
## approxiamtion of block orgins

# %%
snp_origin_bio1['id'] = snp_origin_bio1['chrom'].astype(str) + '_' + snp_origin_bio1['pos'].astype(str)

# %%
snp_origin_bio1['blocks'] = snp_origin_bio1['id'].map(reverse_mapping)

# %%
snp_origin_bio1.groupby('blocks')['snp_origin_bio1'].sum()
# Out:
# blocks
# 1_0       919.659175
# 1_1         7.343712
# 1_10       60.806970
# 1_100     300.696237
# 1_1000     28.040282
#              ...
# 5_995     210.913838
# 5_996       8.793078
# 5_997     142.816520
# 5_998      52.434528
# 5_999      73.129603
# Name: snp_origin_bio1, Length: 16917, dtype: float64

# %%
block_origin_bio1 = snp_origin_bio1.groupby('blocks')['snp_origin_bio1'].mean().reset_index()

# %%
block_origin_bio1.to_csv('../key_files/block_origin_bio1_1001g.csv',index=None)

# %%
snp_origin_bio1 = pd.read_csv('../key_files/snp_origin_bio1_grenenetvcf.csv')

# %%
dict_snps = pd.read_csv('../key_files/var_pos_grenenet.csv')

# %%
snp_origin_bio1 = pd.concat([dict_snps['id'], snp_origin_bio1],axis=1)

# %%
lfmm_results1 = pd.read_csv('../lfmm_full_last_gen/lfmm_fullresults_all_k/lfmm_bio1_k16_results.csv')

lfmm_results2 = pd.read_csv('../lfmm_full_last_gen/lfmm_fullresults_all_k/effect_sizes_simple_full_genome_bio1_k16.csv')

# %%
lfmm_results = pd.concat([lfmm_results1,lfmm_results2],axis=1)

# %%
lfmm_index = dict_snps[dict_snps['total_alleles05filter_lastgen'].notna()]['id'].reset_index(drop=True)

lfmm_results = pd.concat([lfmm_results, lfmm_index],axis=1)

# %%
snp_origin_beta_lfmm = snp_origin_bio1.merge(lfmm_results)

snp_origin_beta_lfmm = snp_origin_beta_lfmm.drop('Unnamed: 0',axis=1)

# %%
th = 0.05/len(snp_origin_beta_lfmm)

# %%
th = 4.768103296189809e-05

# %%
sign_snp_origin_beta_lfmm = snp_origin_beta_lfmm[snp_origin_beta_lfmm['p_value'] < th]

# %%
sign_snp_origin_beta_lfmm
# Out:
#                  id  chrom       pos  snp_origin_bio1      snp_id  \
# 331         1_64817      1     64817         6.206331     1_64817
# 372         1_69718      1     69718         7.648359     1_69718
# 374         1_69773      1     69773         7.575289     1_69773
# 376         1_69805      1     69805         7.698268     1_69805
# 455         1_79418      1     79418        10.039935     1_79418
# ...             ...    ...       ...              ...         ...
# 1047750  5_26854784      5  26854784         8.668975  5_26854784
# 1047751  5_26854885      5  26854885         8.668975  5_26854885
# 1047752  5_26854942      5  26854942         8.668975  5_26854942
# 1048089  5_26901537      5  26901537         2.084957  5_26901537
# 1048090  5_26901571      5  26901571         1.171753  5_26901571
#
#               p_value  significant   block      bio1
# 331      2.332589e-06        False    1_11  0.040456
# 372      2.234159e-05        False    1_11  0.035971
# 374      1.896087e-05        False    1_11  0.035708
# 376      1.834065e-05        False    1_11  0.035774
# 455      1.704281e-05        False    1_11  0.037111
# ...               ...          ...     ...       ...
# 1047750  8.433580e-07        False  5_3109 -0.048469
# 1047751  8.433580e-07        False  5_3109 -0.048469
# 1047752  8.433580e-07        False  5_3109 -0.048469
# 1048089  2.583785e-05        False  5_3109  0.024366
# 1048090  8.550437e-07        False  5_3109  0.023376
#
# [4721 rows x 9 columns]

# %%
snp_origin_beta_lfmm_s = snp_origin_beta_lfmm.sample(10000)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Assuming snp_origin_beta_binomial_reg is your DataFrame with SNP data
# Calculate the KDE for 'snp_origin_bio1' and 'slope'
values = np.vstack([snp_origin_beta_lfmm_s["snp_origin_bio1"], snp_origin_beta_lfmm_s["bio1"]])
kernel = stats.gaussian_kde(values)(values)

# Create a scatter plot using density for color
fig, ax = plt.subplots(figsize=(12, 6))
sns.scatterplot(
    data=snp_origin_beta_lfmm_s,
    x='snp_origin_bio1',
    y='bio1',
    hue=kernel,  # Use the density as color
    palette="viridis",  # Color mapping
    edgecolor="none",  # Remove white edge around the dots
    alpha=0.3,  # Set transparency
    ax=ax
)

# Add a color bar to show the density scale
norm = plt.Normalize(kernel.min(), kernel.max())
sm = plt.cm.ScalarMappable(cmap="viridis", norm=norm)
sm.set_array([])
fig.colorbar(sm, ax=ax, label='Density')
plt.ylabel('Slope LFMM')
# Display the plot
plt.show()

# %%
binomial_reg = pd.read_csv('../binomial_regression_lastgen/binomial_reg_results_last_gen.csv')

binomial_reg_id = dict_snps[dict_snps['total_alleles05filter_lastgen'].notna()]['id'].reset_index(drop=True)

binomial_reg = pd.concat([binomial_reg, binomial_reg_id],axis=1)

snp_origin_beta_binomial_reg = snp_origin_bio1.merge(binomial_reg)

# %%
snp_origin_beta_binomial_reg
# Out:
#                  id  chrom       pos  snp_origin_bio1     slope  \
# 0             1_346      1       346         5.149026  0.011711
# 1             1_353      1       353         1.413023  0.118647
# 2             1_363      1       363         1.734019 -0.085795
# 3             1_395      1       395         1.604329  0.588284
# 4             1_396      1       396         1.604329  0.588284
# ...             ...    ...       ...              ...       ...
# 1048630  5_26975078      5  26975078        15.907648 -0.291705
# 1048631  5_26975121      5  26975121         1.434812 -0.048737
# 1048632  5_26975148      5  26975148         1.434812 -0.048737
# 1048633  5_26975272      5  26975272         7.863781  0.085222
# 1048634  5_26975288      5  26975288         3.815440 -0.169848
#
#                 pvalue      snp_id
# 0         3.863672e-01       1_346
# 1         3.406636e-07       1_353
# 2         3.395036e-05       1_363
# 3        2.536460e-138       1_395
# 4        2.536460e-138       1_396
# ...                ...         ...
# 1048630   1.978042e-74  5_26975078
# 1048631   3.903883e-02  5_26975121
# 1048632   3.903883e-02  5_26975148
# 1048633   5.859110e-12  5_26975272
# 1048634   5.251040e-25  5_26975288
#
# [1048635 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

# %%
sns.kdeplot(
    data =  snp_origin_beta_binomial_reg, x = 'snp_origin_bio1', y = 'slope',
    fill=True, thresh=0, levels=100, cmap="mako",
)

# %%
sns.kdeplot(
    data =  snp_origin_beta_binomial_reg.sample(10000), x = 'snp_origin_bio1', y = 'slope', fill=True,
    levels=10, thresh=.2,
)
# Out:
# <Axes: xlabel='snp_origin_bio1', ylabel='slope'>

# %%
0.05/len(snp_origin_beta_binomial_reg)
# Out:
# 4.768103296189809e-08

# %%
sign = snp_origin_beta_binomial_reg[snp_origin_beta_binomial_reg['pvalue'] < 4.768103296189809e-08]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(16, 8))

# Create a scatter plot without white edges around the dots
sns.scatterplot(
    data=snp_origin_beta_binomial_reg.sample(1000000),
    x='snp_origin_bio1',
    y='slope',
    alpha=0.3,
    edgecolor= None  # This removes the edge color
)

# Set the y-axis label
plt.ylabel('Slope Value')

# Display the plot
plt.show()

# %%
snp_origin_beta_binomial_reg_s = snp_origin_beta_binomial_reg.sample(10000)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Assuming snp_origin_beta_binomial_reg is your DataFrame with SNP data
# Calculate the KDE for 'snp_origin_bio1' and 'slope'
values = np.vstack([snp_origin_beta_binomial_reg_s["snp_origin_bio1"], snp_origin_beta_binomial_reg_s["slope"]])
kernel = stats.gaussian_kde(values)(values)

# Create a scatter plot using density for color
fig, ax = plt.subplots(figsize=(12, 6))
sns.scatterplot(
    data=snp_origin_beta_binomial_reg_s,
    x='snp_origin_bio1',
    y='slope',
    hue=kernel,  # Use the density as color
    palette="viridis",  # Color mapping
    edgecolor="none",  # Remove white edge around the dots
    alpha=0.3,  # Set transparency
    ax=ax
)

# Add a color bar to show the density scale
norm = plt.Normalize(kernel.min(), kernel.max())
sm = plt.cm.ScalarMappable(cmap="viridis", norm=norm)
sm.set_array([])
fig.colorbar(sm, ax=ax, label='Density')
plt.ylabel('Slope binomial Reg')
# Display the plot
plt.show()
